# %%
# load important modules
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# import datetime as dt  # only needed in case of imputation of inicio cuadro clinico
from sklearn.metrics import accuracy_score, precision_score, roc_auc_score, f1_score, hamming_loss, recall_score
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import VarianceThreshold, SelectKBest, f_classif, chi2
from sklearn.svm import SVC
from sklearn import preprocessing
from sklearn.inspection import permutation_importance
import tensorflow as tf
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import Sequential
from keras.layers import Dense
import eli5
from eli5.sklearn import PermutationImportance
# %matplotlib inline

# ignore warning
import warnings
warnings.filterwarnings('ignore')

# %%
# load dataset
data = pd.DataFrame(pd.read_excel(
        "data/COVIDBaja- completa y ESTADISTICA.xlsx-20211001T105600Z-001/COVIDBaja- completa y ESTADISTICA.xlsx"))

# %%
# if rerunning this cell without reloading the dataset: comment lines containing deleted features

# general error fixing and deleting defective rows
# drop empty and defectiv rows (only ID has a value)
data.drop(data[data['PACIENTE'].isna()].index, inplace=True)
data.drop(index=data[data['DEFUNCION'].isna() & (data['MOTIVO_EGRESO']==4.0)].index, inplace=True)

# correct data error in RESULTDADO_DE MUESTRA1
data['RESULTADO_DE MUESTRA1'].replace({-1 : 0, 2:1, 3:1}, inplace=True)
# fix error in Fecha inicio cuadro clinico
data['FECHA_INICIO_CUADRO_CLINICO'].replace({'2019-01-28' : pd.to_datetime('2020-01-28'), '2019-02-24':pd.to_datetime('2020-02-24')}, inplace=True)
# change row (Index: 880) with previous illnesses of value 2 to 1
for i in range(data.shape[1]): data.iloc[:,i].replace({2:1}, inplace=True)

# Replacements of values for better calculation
data['INDICADOR_SOSP_COVID'].replace({'SI' : 1.0, 'NO' :0.0}, inplace = True)
# change nan to 0 or other values
data['DEFUNCION'].fillna(0, inplace=True)
data['CIE10_DIAGNOSTICO_FINAL'].fillna('0000', inplace=True)
data['DIAGNOSTICO_EGRESO_1'].fillna("0000",inplace=True)
data['DIAGNOSTICO_EGRESO_2'].fillna('0000', inplace=True)
data['DIAGNOSTICO_EGRESO_3'].fillna('0000', inplace = True)
# Imputation for Estancia Hosp
data['ESTANCIA_HOSP'].fillna("NO HOSP", inplace=True)

# uniform naming of attributes
data['OCUPACION'].replace({'empleado' : 'Empleado', 'enfermero' : 'Enfermeras', 'Trabajador informal' : 'Trabajador Informal'}, inplace=True)

# change datetype from datetime.time to datetime, fix broken date (if not set manually to nan it will be current date)
data['FECHA_INGRESO.1'].iloc[2480] = np.nan
data['FECHA_INGRESO.1'] = data['FECHA_INGRESO.1'].apply(lambda x : pd.to_datetime(str(x)))

# %%
# Imputation of Fecha Inicio Cuadro Clinico with mean difference to Fecha Ingreso
#df_help = pd.DataFrame(columns = ['DIF_INGRESO_INICIO'])
#df_help['DIF_INGRESO_INICIO'] = data['FECHA_INGRESO'] - data['FECHA_INICIO_CUADRO_CLINICO']
#data['FECHA_INICIO_CUADRO_CLINICO'].fillna(data['FECHA_INGRESO'] + dt.timedelta(df_help['DIF_INGRESO_INICIO'].mean().days),\
#                                           inplace=True)

# %%
# get subset with DMET = Caso grave or DMET = Caso no grave
print(data['DESC_MOTIVO_EGRESO_TIPSERVICIO'].value_counts(dropna=False))
# change nan in target variable so it can get drawn as well
data['DESC_MOTIVO_EGRESO_TIPSERVICIO'].fillna('TRATAMIENTO EN CASA', inplace=True)
fill_up = data[data['DESC_MOTIVO_EGRESO_TIPSERVICIO']=='TRATAMIENTO EN CASA']
data = data[(data['DESC_MOTIVO_EGRESO_TIPSERVICIO']=='CASO GRAVE') | (data['DESC_MOTIVO_EGRESO_TIPSERVICIO'] == 'CASO NO GRAVE')]

# make data set balanced, fill up mild cases with ambulatory cases
data = data.append(fill_up.sample(n=680, random_state=42))
data['DESC_MOTIVO_EGRESO_TIPSERVICIO'].replace({'TRATAMIENTO EN CASA' : 'CASO NO GRAVE'}, inplace=True)
data['DESC_MOTIVO_EGRESO_TIPSERVICIO'].replace({'CASO GRAVE' : 1, 'CASO NO GRAVE' : 0}, inplace=True)
# Out:
# TRATAMIENTO EN CASA    3433
# CASO GRAVE             1206
# NaN                    1192
# CASO NO GRAVE           526
# Name: DESC_MOTIVO_EGRESO_TIPSERVICIO, dtype: int64

# %%
# necessary functions, run this cell only once!

# encoding of datetime features as seconds since epoch
# input: df which shall be encoded, dataframe time_feat containing only the values of datetime features
def dt_encoding(time_feat, df):
    for feat in time_feat:
        if feat in df.columns:
            df[feat] = time_feat[feat].values.astype('int64')// 10 ** 9
            df[feat].where(df[feat] > 0, 0, inplace=True)
    return df

# decoding of datetime features encoded with the above method
# input: df which shall be decoded, dataframe time_feat containing only the values of datetime features
# negative values are decoded as nan
def dt_decoding(time_feat, df):
    for feat in time_feat:
        # decode negative values as nans
        df[feat].where(df[feat] > 0, np.nan, inplace=True)
        df[feat] = pd.to_datetime(df.loc[:,feat]*10**9, unit='ns')
    return df

# deleting features
# input: df where feature should be droped, list of features to drop
def drop_feat(df, to_drop):
    for i in to_drop:
        if i in df.columns:
            df.drop(i, axis = 1, inplace=True)
    return df

# get binary features which should be droped because of too low variance
def drop_var(df):
    bin_features = df.select_dtypes(include=['number'])

    # get binary features
    for i in range(data.select_dtypes(include=['number']).shape[1]):
        if (len(np.unique(data.select_dtypes(include='number').iloc[:,i])) <= 2):
            continue
        else:
            bin_features = bin_features.drop(data.select_dtypes(include=['number']).columns[i], axis=1)
        
    # apply variance threshold
    sel = VarianceThreshold(threshold=(0.95*(1-0.95)))
    sel.fit_transform(bin_features)
    mask = sel.get_support()
    drop_var = []

    # get names of binary features with reasonable variance
    for i in range(len(bin_features.columns)):
        if not mask[i]: drop_var.append(bin_features.columns[i])
    return drop_var

# necessary variables
times = data.select_dtypes(include='datetime')
categorical = data.select_dtypes(include='object')

# %%
# calculation of pearson matrix
corr = data.corr('pearson')

# get features with strong relation in medicine
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6107969/
very_high_correlation = [] # 0.75 to 1.0
for i in range(len(corr)):
    for j in range(i):
        pearson_corr = np.abs(corr.iloc[i,j])
        if 0.75 <= pearson_corr:
            very_high_correlation.append((corr.columns[i], corr.columns[j]))

# %%
for i in very_high_correlation:
    print(str(i)+': '+str(corr.loc[i[0], i[1]]))
    
very_high_correlation = pd.DataFrame(very_high_correlation)
# Out:
# ('ARTRALGIAS', 'MIALGIAS'): 0.8373002033966889
# ('POLIPNEA', 'CIANOSIS'): 1.0
# ('DIAS_PUERP', 'PUERPERIO'): 0.772840833378098
# ('DIAGNOSTICO_CONFIRMADO', 'RESULTADO_DE MUESTRA1'): 0.9621419139173231
# ('MOTIVO_EGRESO', 'DEFUNCION'): 0.8625266340283171

# %%
# display correlation matrix
corr.dropna(how='all').dropna(how='all',axis=1).style.background_gradient(cmap='RdBu', vmax=1, vmin=-1)
# Out:
# <style type="text/css">
# #T_287f5_row0_col0, #T_287f5_row1_col1, #T_287f5_row2_col2, #T_287f5_row3_col3, #T_287f5_row4_col4, #T_287f5_row5_col5, #T_287f5_row6_col6, #T_287f5_row7_col7, #T_287f5_row8_col8, #T_287f5_row9_col9, #T_287f5_row10_col10, #T_287f5_row11_col11, #T_287f5_row12_col12, #T_287f5_row13_col13, #T_287f5_row14_col14, #T_287f5_row15_col15, #T_287f5_row16_col16, #T_287f5_row17_col17, #T_287f5_row17_col20, #T_287f5_row18_col18, #T_287f5_row19_col19, #T_287f5_row20_col17, #T_287f5_row20_col20, #T_287f5_row21_col21, #T_287f5_row22_col22, #T_287f5_row23_col23, #T_287f5_row24_col24, #T_287f5_row25_col25, #T_287f5_row26_col26, #T_287f5_row27_col27, #T_287f5_row28_col28, #T_287f5_row29_col29, #T_287f5_row30_col30, #T_287f5_row31_col31, #T_287f5_row32_col32, #T_287f5_row33_col33, #T_287f5_row34_col34, #T_287f5_row35_col35, #T_287f5_row36_col36, #T_287f5_row37_col37, #T_287f5_row38_col38, #T_287f5_row39_col39, #T_287f5_row40_col40, #T_287f5_row41_col41, #T_287f5_row42_col42, #T_287f5_row43_col43, #T_287f5_row44_col44, #T_287f5_row45_col45, #T_287f5_row46_col46, #T_287f5_row47_col47, #T_287f5_row48_col48, #T_287f5_row49_col49, #T_287f5_row50_col50, #T_287f5_row51_col51, #T_287f5_row52_col52, #T_287f5_row53_col53, #T_287f5_row54_col54, #T_287f5_row55_col55 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_287f5_row0_col1, #T_287f5_row1_col0 {
#   background-color: #e6866a;
#   color: #f1f1f1;
# }
# #T_287f5_row0_col2, #T_287f5_row2_col0, #T_287f5_row22_col33, #T_287f5_row33_col22 {
#   background-color: #fae8de;
#   color: #000000;
# }
# #T_287f5_row0_col3, #T_287f5_row0_col55, #T_287f5_row1_col35, #T_287f5_row3_col0, #T_287f5_row3_col33, #T_287f5_row9_col26, #T_287f5_row12_col27, #T_287f5_row21_col33, #T_287f5_row26_col9, #T_287f5_row27_col12, #T_287f5_row33_col3, #T_287f5_row33_col21, #T_287f5_row33_col40, #T_287f5_row35_col1, #T_287f5_row40_col33, #T_287f5_row55_col0 {
#   background-color: #f9efe9;
#   color: #000000;
# }
# #T_287f5_row0_col4, #T_287f5_row0_col44, #T_287f5_row4_col0, #T_287f5_row44_col0 {
#   background-color: #f8bda1;
#   color: #000000;
# }
# #T_287f5_row0_col5, #T_287f5_row0_col27, #T_287f5_row5_col0, #T_287f5_row27_col0 {
#   background-color: #f9c6ac;
#   color: #000000;
# }
# #T_287f5_row0_col6, #T_287f5_row0_col31, #T_287f5_row1_col34, #T_287f5_row6_col0, #T_287f5_row31_col0, #T_287f5_row33_col52, #T_287f5_row34_col1, #T_287f5_row52_col33 {
#   background-color: #fae9df;
#   color: #000000;
# }
# #T_287f5_row0_col7, #T_287f5_row2_col19, #T_287f5_row2_col43, #T_287f5_row4_col31, #T_287f5_row5_col42, #T_287f5_row5_col44, #T_287f5_row6_col50, #T_287f5_row7_col0, #T_287f5_row7_col21, #T_287f5_row7_col41, #T_287f5_row8_col42, #T_287f5_row9_col18, #T_287f5_row11_col24, #T_287f5_row13_col16, #T_287f5_row13_col22, #T_287f5_row14_col19, #T_287f5_row14_col25, #T_287f5_row14_col44, #T_287f5_row15_col24, #T_287f5_row16_col13, #T_287f5_row16_col55, #T_287f5_row17_col41, #T_287f5_row17_col46, #T_287f5_row18_col9, #T_287f5_row18_col53, #T_287f5_row19_col2, #T_287f5_row19_col14, #T_287f5_row19_col23, #T_287f5_row19_col24, #T_287f5_row20_col41, #T_287f5_row20_col46, #T_287f5_row21_col7, #T_287f5_row22_col13, #T_287f5_row22_col39, #T_287f5_row22_col45, #T_287f5_row23_col19, #T_287f5_row24_col11, #T_287f5_row24_col15, #T_287f5_row24_col19, #T_287f5_row24_col44, #T_287f5_row25_col14, #T_287f5_row26_col55, #T_287f5_row27_col29, #T_287f5_row29_col27, #T_287f5_row29_col47, #T_287f5_row29_col49, #T_287f5_row30_col40, #T_287f5_row30_col44, #T_287f5_row30_col47, #T_287f5_row31_col4, #T_287f5_row31_col38, #T_287f5_row31_col43, #T_287f5_row33_col35, #T_287f5_row35_col33, #T_287f5_row38_col31, #T_287f5_row39_col22, #T_287f5_row40_col30, #T_287f5_row40_col45, #T_287f5_row41_col7, #T_287f5_row41_col17, #T_287f5_row41_col20, #T_287f5_row41_col44, #T_287f5_row42_col5, #T_287f5_row42_col8, #T_287f5_row42_col54, #T_287f5_row43_col2, #T_287f5_row43_col31, #T_287f5_row43_col53, #T_287f5_row44_col5, #T_287f5_row44_col14, #T_287f5_row44_col24, #T_287f5_row44_col30, #T_287f5_row44_col41, #T_287f5_row45_col22, #T_287f5_row45_col40, #T_287f5_row46_col17, #T_287f5_row46_col20, #T_287f5_row46_col48, #T_287f5_row47_col29, #T_287f5_row47_col30, #T_287f5_row48_col46, #T_287f5_row49_col29, #T_287f5_row50_col6, #T_287f5_row52_col55, #T_287f5_row53_col18, #T_287f5_row53_col43, #T_287f5_row54_col42, #T_287f5_row55_col16, #T_287f5_row55_col26, #T_287f5_row55_col52 {
#   background-color: #eaf1f5;
#   color: #000000;
# }
# #T_287f5_row0_col8, #T_287f5_row0_col39, #T_287f5_row5_col33, #T_287f5_row8_col0, #T_287f5_row33_col5, #T_287f5_row39_col0 {
#   background-color: #fbe4d6;
#   color: #000000;
# }
# #T_287f5_row0_col9, #T_287f5_row2_col28, #T_287f5_row7_col40, #T_287f5_row7_col44, #T_287f5_row7_col46, #T_287f5_row9_col0, #T_287f5_row12_col22, #T_287f5_row15_col40, #T_287f5_row19_col53, #T_287f5_row22_col12, #T_287f5_row28_col2, #T_287f5_row40_col7, #T_287f5_row40_col15, #T_287f5_row44_col7, #T_287f5_row46_col7, #T_287f5_row53_col19 {
#   background-color: #f9eee7;
#   color: #000000;
# }
# #T_287f5_row0_col10, #T_287f5_row1_col15, #T_287f5_row1_col32, #T_287f5_row1_col36, #T_287f5_row2_col26, #T_287f5_row2_col35, #T_287f5_row2_col36, #T_287f5_row4_col51, #T_287f5_row7_col27, #T_287f5_row7_col55, #T_287f5_row10_col0, #T_287f5_row10_col55, #T_287f5_row11_col38, #T_287f5_row12_col16, #T_287f5_row12_col25, #T_287f5_row13_col33, #T_287f5_row15_col1, #T_287f5_row16_col12, #T_287f5_row25_col12, #T_287f5_row26_col2, #T_287f5_row27_col7, #T_287f5_row32_col1, #T_287f5_row33_col13, #T_287f5_row33_col41, #T_287f5_row33_col42, #T_287f5_row35_col2, #T_287f5_row36_col1, #T_287f5_row36_col2, #T_287f5_row38_col11, #T_287f5_row41_col33, #T_287f5_row42_col33, #T_287f5_row51_col4, #T_287f5_row55_col7, #T_287f5_row55_col10 {
#   background-color: #f9f0eb;
#   color: #000000;
# }
# #T_287f5_row0_col11, #T_287f5_row0_col17, #T_287f5_row0_col20, #T_287f5_row11_col0, #T_287f5_row12_col52, #T_287f5_row17_col0, #T_287f5_row20_col0, #T_287f5_row52_col12 {
#   background-color: #fce2d2;
#   color: #000000;
# }
# #T_287f5_row0_col12, #T_287f5_row1_col8, #T_287f5_row2_col39, #T_287f5_row2_col53, #T_287f5_row4_col24, #T_287f5_row4_col42, #T_287f5_row6_col31, #T_287f5_row8_col1, #T_287f5_row8_col18, #T_287f5_row10_col14, #T_287f5_row10_col16, #T_287f5_row11_col30, #T_287f5_row11_col43, #T_287f5_row11_col45, #T_287f5_row12_col0, #T_287f5_row13_col38, #T_287f5_row14_col10, #T_287f5_row15_col19, #T_287f5_row16_col10, #T_287f5_row16_col29, #T_287f5_row17_col21, #T_287f5_row18_col8, #T_287f5_row18_col31, #T_287f5_row18_col38, #T_287f5_row19_col15, #T_287f5_row19_col27, #T_287f5_row20_col21, #T_287f5_row21_col17, #T_287f5_row21_col20, #T_287f5_row21_col44, #T_287f5_row23_col52, #T_287f5_row24_col4, #T_287f5_row24_col26, #T_287f5_row26_col24, #T_287f5_row26_col40, #T_287f5_row26_col42, #T_287f5_row26_col50, #T_287f5_row27_col19, #T_287f5_row27_col39, #T_287f5_row27_col47, #T_287f5_row28_col51, #T_287f5_row29_col16, #T_287f5_row30_col11, #T_287f5_row31_col6, #T_287f5_row31_col18, #T_287f5_row38_col13, #T_287f5_row38_col18, #T_287f5_row39_col2, #T_287f5_row39_col27, #T_287f5_row39_col45, #T_287f5_row40_col26, #T_287f5_row42_col4, #T_287f5_row42_col26, #T_287f5_row43_col11, #T_287f5_row44_col21, #T_287f5_row45_col11, #T_287f5_row45_col39, #T_287f5_row46_col49, #T_287f5_row46_col50, #T_287f5_row47_col27, #T_287f5_row49_col46, #T_287f5_row50_col26, #T_287f5_row50_col46, #T_287f5_row51_col28, #T_287f5_row52_col23, #T_287f5_row53_col2 {
#   background-color: #e9f0f4;
#   color: #000000;
# }
# #T_287f5_row0_col13, #T_287f5_row1_col37, #T_287f5_row2_col14, #T_287f5_row2_col27, #T_287f5_row3_col22, #T_287f5_row3_col52, #T_287f5_row4_col48, #T_287f5_row5_col35, #T_287f5_row5_col48, #T_287f5_row6_col29, #T_287f5_row6_col46, #T_287f5_row6_col55, #T_287f5_row7_col16, #T_287f5_row7_col42, #T_287f5_row12_col26, #T_287f5_row12_col33, #T_287f5_row12_col55, #T_287f5_row13_col0, #T_287f5_row14_col2, #T_287f5_row15_col50, #T_287f5_row15_col52, #T_287f5_row16_col7, #T_287f5_row22_col3, #T_287f5_row24_col33, #T_287f5_row

# %%
# drop features
time_drop = list(times.columns)

# low variance
var_drop = drop_var(data)
var_drop = var_drop + ['DESC_DIAGNOSTICO_EGRESO_1', 'DESC_DIAGNOSTICO_EGRESO_2', 'DESC_DIAGNOSTICO_EGRESO_3', 'SEMANAS_DE_GESTACION']
print("Drop because of low variance: \n", var_drop)

# high correlation
print('Drop one because of high correlation to other feature:\n', very_high_correlation)

# equals other feature or nan
contained_drop = [
    'F_REGISTRO_DEFUNCION','FECHA_DEFUNCION','FECHA_MUESTRA_CONF2',\
    'DESC_TIPO_MUESTRA_2','DESC_ESTATUS_CONF2','DESC_TIPO_INFLUENZA_CONF2',\
    'TIPO_INFLUENZA_CONF1', 'TIPO_INFLUENZA_CONF2','TIPO_MUESTRA_CONF_1',\
    'TIPO_MUESTRA_CONF_2','RESULTADO_DE MUESTRA2','CIE10_DIAGNOSTICO_FINAL',\
    'DIAGNOSTICO_EGRESO_1', 'DIAGNOSTICO_EGRESO_2', 'DIAGNOSTICO_EGRESO_3',\
    'DESC_TIPO_INFLUENZA_CONF1', 'FECHA_INGRESO.1'
]
print('Drop because contained by another feature:\n', contained_drop)

drop_high_corr = []
for i in range(len(very_high_correlation[0])):
    feat0 = very_high_correlation[0][i]
    feat1 = very_high_correlation[1][i]
    # check if one feature has low variance
    if feat0 =='MOTIVO_EGRESO'or feat1=='MOTIVO_EGRESO':
        drop_high_corr.append(feat0)
        drop_high_corr.append(feat1)
    elif feat0 in var_drop or feat1 in var_drop:
        drop_high_corr.append(feat1)
        drop_high_corr.append(feat0)
        continue
    elif feat0 not in drop_high_corr:
        drop_high_corr.append(feat0)
        
to_drop = contained_drop+var_drop+drop_high_corr+['ID', 'PACIENTE']+time_drop
data = drop_feat(data, to_drop)
print(np.unique(to_drop))
# Out:
# Drop because of low variance:
#  ['CONGESTION_NASAL', 'DISFONIA', 'LUMBALGIA', 'ANTECED_ASMA', 'ANTECED_INMUNOSUPRESION', 'ANTECED_VIH_EVIH', 'EMBARAZO', 'LACTANCIA', 'PUERPERIO', 'TIENE_INTUBACION_ENDOTRAQUEAL', 'ANTECED_CARDIOVASCULAR', 'ANT_ENF_HEPATICA_CRONICA', 'ANT_ANEMIA_HEMOLITICA', 'ANT_ENF_NEUROLOGICA', 'RECIBIO_VAC_NEUMOCOCO', 'DESC_VARIANTE_INFLUENZA', 'ANTECED_TUBERCULOSIS', 'ANTECED_CANCER', 'DESC_DIAGNOSTICO_EGRESO_1', 'DESC_DIAGNOSTICO_EGRESO_2', 'DESC_DIAGNOSTICO_EGRESO_3', 'SEMANAS_DE_GESTACION']
# Drop one because of high correlation to other feature:
#                          0                      1
# 0              ARTRALGIAS               MIALGIAS
# 1                POLIPNEA               CIANOSIS
# 2              DIAS_PUERP              PUERPERIO
# 3  DIAGNOSTICO_CONFIRMADO  RESULTADO_DE MUESTRA1
# 4           MOTIVO_EGRESO              DEFUNCION
# Drop because contained by another feature:
#  ['F_REGISTRO_DEFUNCION', 'FECHA_DEFUNCION', 'FECHA_MUESTRA_CONF2', 'DESC_TIPO_MUESTRA_2', 'DESC_ESTATUS_CONF2', 'DESC_TIPO_INFLUENZA_CONF2', 'TIPO_INFLUENZA_CONF1', 'TIPO_INFLUENZA_CONF2', 'TIPO_MUESTRA_CONF_1', 'TIPO_MUESTRA_CONF_2', 'RESULTADO_DE MUESTRA2', 'CIE10_DIAGNOSTICO_FINAL', 'DIAGNOSTICO_EGRESO_1', 'DIAGNOSTICO_EGRESO_2', 'DIAGNOSTICO_EGRESO_3', 'DESC_TIPO_INFLUENZA_CONF1', 'FECHA_INGRESO.1']
# ['ANTECED_ASMA' 'ANTECED_CANCER' 'ANTECED_CARDIOVASCULAR'
#  'ANTECED_INMUNOSUPRESION' 'ANTECED_TUBERCULOSIS' 'ANTECED_VIH_EVIH'
#  'ANT_ANEMIA_HEMOLITICA' 'ANT_ENF_HEPATICA_CRONICA' 'ANT_ENF_NEUROLOGICA'
#  'ARTRALGIAS' 'CIE10_DIAGNOSTICO_FINAL' 'CONGESTION_NASAL' 'DEFUNCION'
#  'DESC_DIAGNOSTICO_EGRESO_1' 'DESC_DIAGNOSTICO_EGRESO_2'
#  'DESC_DIAGNOSTICO_EGRESO_3' 'DESC_ESTATUS_CONF2'
#  'DESC_TIPO_INFLUENZA_CONF1' 'DESC_TIPO_INFLUENZA_CONF2'
#  'DESC_TIPO_MUESTRA_2' 'DESC_VARIANTE_INFLUENZA' 'DIAGNOSTICO_CONFIRMADO'
#  'DIAGNOSTICO_EGRESO_1' 'DIAGNOSTICO_EGRESO_2' 'DIAGNOSTICO_EGRESO_3'
#  'DIAS_PUERP' 'DISFONIA' 'EMBARAZO' 'FECHA_DEFUNCION'
#  'FECHA_EGRESO_O_DEFUNCION' 'FECHA_INGRESO' 'FECHA_INGRESO.1'
#  'FECHA_INICIO_CUADRO_CLINICO' 'FECHA_MUESTRA_CONF1' 'FECHA_MUESTRA_CONF2'
#  'FECHA_VAC_NEUMOCOCO' 'F_REGISTRO_DEFUNCION' 'F_REGISTRO_EGRESO'
#  'F_REGISTRO_RESULT_CONF1' 'F_REGISTRO_RESULT_CONF2' 'ID' 'LACTANCIA'
#  'LUMBALGIA' 'MOTIVO_EGRESO' 'PACIENTE' 'POLIPNEA' 'PUERPERIO'
#  'RECIBIO_VAC_NEUMOCOCO' 'RESULTADO_DE MUESTRA2' 'SEMANAS_DE_GESTACION'
#  'TIENE_INTUBACION_ENDOTRAQUEAL' 'TIPO_INFLUENZA_CONF1'
#  'TIPO_INFLUENZA_CONF2' 'TIPO_MUESTRA_CONF_1' 'TIPO_MUESTRA_CONF_2']
# (2412, 37)

# %%
# encoding and splitting in train, test and validation set
X = data.drop('DESC_MOTIVO_EGRESO_TIPSERVICIO', axis=1)
y = data['DESC_MOTIVO_EGRESO_TIPSERVICIO']

# one hot encoding of categorical features
X_enc = pd.get_dummies(X, columns=X.select_dtypes(include='object').columns,\
                      prefix=X.select_dtypes(include='object').columns)
X_enc = X_enc.select_dtypes(include='number')
# encoding of target variable, only really necessary if non-binary classifier used
le = preprocessing.LabelEncoder()
le.fit(y)
y_enc = le.transform(y)

X_train, X_test, y_train, y_test = train_test_split(X_enc, y_enc, test_size=0.2, random_state=42)
y_train_ohe = tf.keras.utils.to_categorical(y_train)
y_test_ohe = tf.keras.utils.to_categorical(y_test)
#X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.5, random_state=42)

# %%
# gridSearch for RF
np.random.seed(1)

rf = RandomForestClassifier(random_state=1)
samples = [i**2 * 10 for i in range(1,8)]
depth = [3,4,5,7,9,15,20,30]
crit = ['entropy', 'gini']
param_grid_rf = dict(n_estimators=samples, max_depth=depth, criterion=crit)
grid_rf = GridSearchCV(estimator=rf, param_grid=param_grid_rf, scoring='accuracy', n_jobs=-1)
grid_result_rf = grid_rf.fit(X_train, y_train)

# %%
# evaluation of gridSearch for RF
print('Best: %f using %s' ,(grid_result_rf.best_score_, grid_result_rf.best_params_))

results_rf = pd.DataFrame(grid_result_rf.cv_results_).sort_values(by=['param_max_depth', 'param_n_estimators'])

fig, (ax1, ax2) = plt.subplots(1,2, figsize=(15,5), sharex=True, sharey=True)

# generating heatmap of paramter grid for rf with crit=gini
hm1 = results_rf[results_rf['param_criterion'] == 'gini'][['param_max_depth', 'param_n_estimators', 'mean_test_score']]
hm1 = hm1.pivot('param_max_depth', 'param_n_estimators', 'mean_test_score')
plt.figure()
heat1 = sns.heatmap(hm1, linewidth = 1 , annot = True, cmap='BuPu', vmax=grid_result_rf.best_score_, vmin=0.79, ax=ax1)
ax1.set_title('Criterion = Gini')
ax1.set_ylabel('Maximum depth of single estimator')
ax1.set_xlabel('Amount of estimators')

# generating heatmap of paramter grid for rf with crit=entropy
hm2 = results_rf[results_rf['param_criterion'] == 'entropy'][['param_max_depth', 'param_n_estimators', 'mean_test_score']]
hm2 = hm2.pivot('param_max_depth', 'param_n_estimators', 'mean_test_score')
plt.figure()
heat2 = sns.heatmap(hm2, linewidth = 1 , annot = True, cmap='BuPu', vmax=grid_result_rf.best_score_, vmin=0.79, ax=ax2)
ax2.set_title('Criterion = Entropy')
ax2.set_ylabel('Maximum depth of single estimator')
ax2.set_xlabel('Amount of estimators')
fig.savefig('pictures/rf_gridsearch_balanced.png')
plt.show()
# Out:
# Best: %f using %s (0.8387753179463024, {'criterion': 'entropy', 'max_depth': 20, 'n_estimators': 490})

# %%
# normalize data
sc = preprocessing.StandardScaler()
sc.fit(X_enc)
X_norm = pd.DataFrame(sc.transform(X_enc), index=X_enc.index, columns=X_enc.columns)

# generate normalised test and training set
X_train_svc, X_test_svc, y_train, y_test = train_test_split(X_norm, y_enc, test_size=0.2, random_state=42)

# %%
np.random.seed(1)

# Grid search for support vector classifier
svc = SVC()
C = [2**i for i in range(-2,5)]
gamma = ['scale', 'auto']
kernel = ['rbf', 'sigmoid']
param_grid_svc = dict(kernel=kernel, C=C, gamma=gamma)
grid_svc = GridSearchCV(estimator=svc, param_grid=param_grid_svc, n_jobs=-1)
grid_result_svc = grid_svc.fit(X_train_svc, y_train)

# %%
# evaluation of gridSearch for RF
print('Best: %f using %s' ,(grid_result_svc.best_score_, grid_result_svc.best_params_))

results_svc = pd.DataFrame(grid_result_svc.cv_results_).sort_values(by='param_C')

fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,3), sharex=True, sharey=True)

# generating heatmap of paramter grid for svc with kernel = rbf
hm1 = results_svc[results_svc['param_kernel']=='rbf'][['param_gamma', 'param_C', 'mean_test_score']]
hm1 = hm1.pivot('param_gamma', 'param_C', 'mean_test_score')
plt.figure()
heat_map1 = sns.heatmap(hm1, linewidth=1, annot=True, cmap='BuPu', vmax=grid_result_rf.best_score_, vmin=0.79, ax=ax1)
ax1.set_title('Kernel = RBF')
ax1.set_ylabel('Gamma')
ax1.set_xlabel('C')


# generating heatmap of paramter grid for rf with crit=entropy
hm2 = results_svc[results_svc['param_kernel']=='sigmoid'][['param_gamma', 'param_C', 'mean_test_score']]
hm2 = hm2.pivot('param_gamma', 'param_C', 'mean_test_score')
plt.figure()
heat_map2 = sns.heatmap(hm2, linewidth=1, annot=True, cmap='BuPu', vmax=grid_result_rf.best_score_, vmin=0.79, ax=ax2)
ax2.set_title('Kernel = Sigmoid')
ax2.set_ylabel('Gamma')
ax2.set_xlabel('C')
fig.savefig('pictures/svc_gridsearch_balanced.png')
plt.show()
# Out:
# Best: %f using %s (0.8268555278917973, {'C': 2, 'gamma': 'auto', 'kernel': 'rbf'})

# %%
tf.keras.backend.set_floatx('float64')
tf.random.set_seed(1)

# normalize data set

# generate NN models
def generate_nn(u, a, optimizer='rmsprop', init='glorot_uniform'):
    model = Sequential()
    for i in range(len(u)):
        model.add(Dense(u[i], kernel_initializer=init, activation=a[i]))
    
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

# generate validation set from training set
X_train_nn, X_test_nn, y_train_nn, y_test_nn = train_test_split(X_norm, y_enc, random_state=1)
X_train_nn, X_val_nn, y_train_nn, y_val_nn = train_test_split(X_train_nn, y_train_nn, test_size=0.2, random_state=1)

# gridSearch for NN
nn_models = []
# generate models and save all trained models
nn01 = KerasClassifier(build_fn=lambda: generate_nn([len(X_train_nn.columns), 256, 2], ['relu', 'relu', 'softmax'], 'adam'), epochs=10)
nn01.fit(X_train_nn, y_train_nn)
nn_models.append(nn01)

nn02 = KerasClassifier(build_fn=lambda: generate_nn([len(X_train_nn.columns), 256, 2], ['sigmoid', 'sigmoid', 'softmax'], 'adam'), epochs=10)
nn02.fit(X_train_nn, y_train_nn)
nn_models.append(nn02)

nn03 = KerasClassifier(build_fn=lambda: generate_nn([len(X_train.columns), 256, 2], ['relu', 'relu', 'sigmoid'], 'adam'), epochs=10)
nn03.fit(X_train_nn, y_train_nn)
nn_models.append(nn03)

nn04 = KerasClassifier(build_fn=lambda: generate_nn([len(X_train.columns), 256, 2], ['softmax', 'softmax', 'sigmoid'], 'adam'), epochs=10)
nn04.fit(X_train_nn, y_train_nn)
nn_models.append(nn04)

    
val_nn = pd.DataFrame(index=['Accuracy', 'Recall', 'Precision', 'F1', 'ROC_AUC', 'Hamming_loss'])
train_nn = pd.DataFrame(index=['Accuracy', 'Recall', 'Precision', 'F1', 'ROC_AUC', 'Hamming_loss'])
for m in nn_models:
    nn_pred = m.predict(X_val_nn)
    nn_train = m.predict(X_train_nn)
        
    # evaluation of trained models
    val_nn['NN_'+str(nn_models.index(m)+1)] = [accuracy_score(y_val_nn, nn_pred),\
                       recall_score(y_val_nn, nn_pred),\
                       precision_score(y_val_nn, nn_pred),\
                       f1_score(y_val_nn, nn_pred),\
                       roc_auc_score(y_val_nn, nn_pred),\
                       hamming_loss(y_val_nn,nn_pred)]
    train_nn['NN_'+str(nn_models.index(m)+1)] = [accuracy_score(y_train_nn, nn_train),\
                       recall_score(y_train_nn, nn_train),\
                       precision_score(y_train_nn, nn_train),\
                       f1_score(y_train_nn, nn_train),\
                       roc_auc_score(y_train_nn, nn_train),\
                       hamming_loss(y_train_nn, nn_train)]
val_nn = val_nn.T
train_nn = train_nn.T
# Out:
# Epoch 1/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4922 - accuracy: 0.7519
# Epoch 2/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3680 - accuracy: 0.8321
# Epoch 3/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3236 - accuracy: 0.8556
# Epoch 4/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2956 - accuracy: 0.8645
# Epoch 5/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2673 - accuracy: 0.8853
# Epoch 6/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2401 - accuracy: 0.9032
# Epoch 7/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2111 - accuracy: 0.9136
# Epoch 8/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1845 - accuracy: 0.9261
# Epoch 9/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1601 - accuracy: 0.9482
# Epoch 10/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1410 - accuracy: 0.9544
# Epoch 1/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6180 - accuracy: 0.6745
# Epoch 2/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4536 - accuracy: 0.8072
# Epoch 3/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4028 - accuracy: 0.8245
# Epoch 4/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3900 - accuracy: 0.8279
# Epoch 5/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3748 - accuracy: 0.8383
# Epoch 6/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3685 - accuracy: 0.8424
# Epoch 7/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3585 - accuracy: 0.8369
# Epoch 8/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3556 - accuracy: 0.8438
# Epoch 9/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3500 - accuracy: 0.8424
# Epoch 10/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3560 - accuracy: 0.8397
# Epoch 1/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4994 - accuracy: 0.7519
# Epoch 2/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3621 - accuracy: 0.8300
# Epoch 3/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3217 - accuracy: 0.8438
# Epoch 4/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2989 - accuracy: 0.8590
# Epoch 5/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2723 - accuracy: 0.8728
# Epoch 6/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2490 - accuracy: 0.8867
# Epoch 7/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2211 - accuracy: 0.9026
# Epoch 8/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1930 - accuracy: 0.9191
# Epoch 9/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1661 - accuracy: 0.9371
# Epoch 10/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1482 - accuracy: 0.9489
# Epoch 1/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6933 - accuracy: 0.5003
# Epoch 2/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6927 - accuracy: 0.5197
# Epoch 3/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6920 - accuracy: 0.5197
# Epoch 4/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6905 - accuracy: 0.5197
# Epoch 5/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6882 - accuracy: 0.5197
# Epoch 6/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6844 - accuracy: 0.5197
# Epoch 7/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6780 - accuracy: 0.5197
# Epoch 8/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6686 - accuracy: 0.6669
# Epoch 9/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6561 - accuracy: 0.8334
# Epoch 10/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6408 - accuracy: 0.8466
# WARNING:tensorflow:From C:\Users\hanna\anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py:241: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %%
print(val_nn.iloc[:,:-1].mean(axis=1).sort_values(ascending=False))

# determinates max (yellow) and min (blue) for each column
val_nn.style.background_gradient(cmap='cividis')
# Out:
# NN_2    0.844639
# NN_4    0.819702
# NN_1    0.804029
# NN_3    0.790306
# dtype: float64
# <style type="text/css">
# #T_d5787_row0_col0, #T_d5787_row3_col5 {
#   background-color: #575d6d;
#   color: #f1f1f1;
# }
# #T_d5787_row0_col1, #T_d5787_row1_col5, #T_d5787_row2_col0, #T_d5787_row2_col1, #T_d5787_row2_col2, #T_d5787_row2_col3, #T_d5787_row2_col4 {
#   background-color: #00224e;
#   color: #f1f1f1;
# }
# #T_d5787_row0_col2 {
#   background-color: #958f77;
#   color: #f1f1f1;
# }
# #T_d5787_row0_col3 {
#   background-color: #3c4a6c;
#   color: #f1f1f1;
# }
# #T_d5787_row0_col4 {
#   background-color: #656870;
#   color: #f1f1f1;
# }
# #T_d5787_row0_col5, #T_d5787_row3_col0 {
#   background-color: #a59c74;
#   color: #f1f1f1;
# }
# #T_d5787_row1_col0, #T_d5787_row1_col1, #T_d5787_row1_col3, #T_d5787_row1_col4, #T_d5787_row2_col5, #T_d5787_row3_col2 {
#   background-color: #fee838;
#   color: #000000;
# }
# #T_d5787_row1_col2 {
#   background-color: #414d6c;
#   color: #f1f1f1;
# }
# #T_d5787_row3_col1 {
#   background-color: #1e3a6f;
#   color: #f1f1f1;
# }
# #T_d5787_row3_col3 {
#   background-color: #7d7c78;
#   color: #f1f1f1;
# }
# #T_d5787_row3_col4 {
#   background-color: #beaf6b;
#   color: #000000;
# }
# </style>
# <table id="T_d5787_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >Recall</th>
#       <th class="col_heading level0 col2" >Precision</th>
#       <th class="col_heading level0 col3" >F1</th>
#       <th class="col_heading level0 col4" >ROC_AUC</th>
#       <th class="col_heading level0 col5" >Hamming_loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5787_level0_row0" class="row_heading level0 row0" >NN_1</th>
#       <td id="T_d5787_row0_col0" class="data row0 col0" >0.792818</td>
#       <td id="T_d5787_row0_col1" class="data row0 col1" >0.839378</td>
#       <td id="T_d5787_row0_col2" class="data row0 col2" >0.786408</td>
#       <td id="T_d5787_row0_col3" class="data row0 col3" >0.812030</td>
#       <td id="T_d5787_row0_col4" class="data row0 col4" >0.789512</td>
#       <td id="T_d5787_row0_col5" class="data row0 col5" >0.207182</td>
#     </tr>
#     <tr>
#       <th id="T_d5787_level0_row1" class="row_heading level0 row1" >NN_2</th>
#       <td id="T_d5787_row1_col0" class="data row1 col0" >0.825967</td>
#       <td id="T_d5787_row1_col1" class="data row1 col1" >0.953368</td>
#       <td id="T_d5787_row1_col2" class="data row1 col2" >0.773109</td>
#       <td id="T_d5787_row1_col3" class="data row1 col3" >0.853828</td>
#       <td id="T_d5787_row1_col4" class="data row1 col4" >0.816921</td>
#       <td id="T_d5787_row1_col5" class="data row1 col5" >0.174033</td>
#     </tr>
#     <tr>
#       <th id="T_d5787_level0_row2" class="row_heading level0 row2" >NN_3</th>
#       <td id="T_d5787_row2_col0" class="data row2 col0" >0.776243</td>
#       <td id="T_d5787_row2_col1" class="data row2 col1" >0.839378</td>
#       <td id="T_d5787_row2_col2" class="data row2 col2" >0.764151</td>
#       <td id="T_d5787_row2_col3" class="data row2 col3" >0.800000</td>
#       <td id="T_d5787_row2_col4" class="data row2 col4" >0.771760</td>
#       <td id="T_d5787_row2_col5" class="data row2 col5" >0.223757</td>
#     </tr>
#     <tr>
#       <th id="T_d5787_level0_row3" class="row_heading level0 row3" >NN_4</th>
#       <td id="T_d5787_row3_col0" class="data row3 col0" >0.809392</td>
#       <td id="T_d5787_row3_col1" class="data row3 col1" >0.854922</td>
#       <td id="T_d5787_row3_col2" class="data row3 col2" >0.800971</td>
#       <td id="T_d5787_row3_col3" class="data row3 col3" >0.827068</td>
#       <td id="T_d5787_row3_col4" class="data row3 col4" >0.806159</td>
#       <td id="T_d5787_row3_col5" class="data row3 col5" >0.190608</td>
#     </tr>
#   </tbody>
# </table>

# %%
tf.random.set_seed(42)
np.random.seed(1)

# grid Search with CV on Model 2 for neural networks
def create_nn02(optimizer='adam', init='glorot_uniform'):
    tf.random.set_seed(42)
    model = Sequential()
    model.add(Dense(79, kernel_initializer=init, activation = 'sigmoid'))
    model.add(Dense(256, kernel_initializer=init, activation = 'sigmoid'))
    model.add(Dense(2, kernel_initializer=init, activation = 'softmax'))
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy', 'mse'])
    return model

nn02 = KerasClassifier(build_fn=create_nn02, verbose=0)
# grid search on epochs, batch size and optimizer
optimizers = ['rmsprop', 'adam']
init = ['glorot_uniform', 'random_normal', 'random_uniform']
epochs = [10, 50, 100]
batches = [5,10,20,50]
param_grid = dict(optimizer=optimizers, epochs=epochs, batch_size=batches, init=init)
grid = GridSearchCV(estimator=nn02, param_grid=param_grid, n_jobs=-1)
grid_result = grid.fit(X_train_svc, y_train)

# %%
# summarize results
# evaluation of gridSearch for RF
print('Best: %f using %s' ,(grid_result.best_score_, grid_result.best_params_))

results_nn = pd.DataFrame(grid_result.cv_results_).sort_values(by='param_epochs')

# generating heatmap of paramter grid for svc with kernel = rbf
hm1 = results_nn[(results_nn['param_init']=='glorot_uniform') & (results_nn['param_optimizer']=='rmsprop')][[ 'param_epochs', 'param_batch_size', 'mean_test_score']]
hm1 = hm1.pivot('param_epochs', 'param_batch_size', 'mean_test_score')

hm2 = results_nn[(results_nn['param_init']=='random_normal') & (results_nn['param_optimizer']=='rmsprop')][[ 'param_epochs', 'param_batch_size', 'mean_test_score']]
hm2 = hm2.pivot('param_epochs', 'param_batch_size', 'mean_test_score')

hm3 = results_nn[(results_nn['param_init']=='random_uniform') & (results_nn['param_optimizer']=='rmsprop')][[ 'param_epochs', 'param_batch_size', 'mean_test_score']]
hm3 = hm3.pivot('param_epochs', 'param_batch_size', 'mean_test_score')

hm4 = results_nn[(results_nn['param_init']=='glorot_uniform') & (results_nn['param_optimizer']=='adam')][[ 'param_epochs', 'param_batch_size', 'mean_test_score']]
hm4 = hm4.pivot('param_epochs', 'param_batch_size', 'mean_test_score')

hm5 = results_nn[(results_nn['param_init']=='random_normal') & (results_nn['param_optimizer']=='adam')][[ 'param_epochs', 'param_batch_size', 'mean_test_score']]
hm5 = hm5.pivot('param_epochs', 'param_batch_size', 'mean_test_score')

hm6 = results_nn[(results_nn['param_init']=='random_uniform') & (results_nn['param_optimizer']=='adam')][[ 'param_epochs', 'param_batch_size', 'mean_test_score']]
hm6 = hm6.pivot('param_epochs', 'param_batch_size', 'mean_test_score')

fig, ax = plt.subplots(2,3, sharex=True, sharey=True, figsize=(20,10))
hm1 = sns.heatmap(hm1, linewidth=1, annot=True, cmap='BuPu', ax=ax[0,0], vmin = 0.79, vmax=grid_result_rf.best_score_)
hm2 = sns.heatmap(hm2, linewidth=1, annot=True, cmap='BuPu', ax=ax[0,1], vmin = 0.79, vmax=grid_result_rf.best_score_)
hm3 = sns.heatmap(hm3, linewidth=1, annot=True, cmap='BuPu', ax=ax[0,2], vmin = 0.79, vmax=grid_result_rf.best_score_)
hm4 = sns.heatmap(hm4, linewidth=1, annot=True, cmap='BuPu', ax=ax[1,0], vmin = 0.79, vmax=grid_result_rf.best_score_)
hm5 = sns.heatmap(hm5, linewidth=1, annot=True, cmap='BuPu', ax=ax[1,1], vmin = 0.79, vmax=grid_result_rf.best_score_)
hm6 = sns.heatmap(hm6, linewidth=1, annot=True, cmap='BuPu', ax=ax[1,2], vmin = 0.79, vmax=grid_result_rf.best_score_)

# add titles per column and row
for i, a in enumerate(ax.flatten()[:6]):
    a.set_ylabel('Epochs')
    if i < 3:
        a.xaxis.set_visible(False)
        a.set_title("Init = "+str(init[i]))
    if i > 2:
        a.set_xlabel('Batch size')
    if i == 0 or i == 3:
        a.set_ylabel('Optimizer = '+str(optimizers[np.sign(i)]))
plt.tight_layout()
plt.savefig('pictures/nn_gridsearch_balanced.png')
plt.show()
# Out:
# Best: %f using %s (0.8253186106681824, {'batch_size': 50, 'epochs': 10, 'init': 'random_normal', 'optimizer': 'adam'})

# %%
# models with best parameters from grid search
rf = RandomForestClassifier(criterion= 'entropy', max_depth= 20, n_estimators=490, random_state=42)
svc = SVC(C=2, gamma='auto', kernel='rbf')
nn = KerasClassifier(build_fn=lambda: create_nn02(init='random_normal',optimizer= 'adam'), batch_size= 50, epochs=10)

# %%
# functions for ranking of features
def topKfeat(score, K):
    cnt = 0
    printed = []
    # get names of features and rank
    ranking = []
    sorted_feat = score.sort_values(0, ascending=False)
    for feat in sorted_feat.Feature:
            if feat not in printed:
                ranking.append([feat, len(ranking)+1])
                printed.append(feat)
            if len(printed) > K-1:
                break
    return pd.DataFrame(data=ranking, columns=["Feature", "Rank"])

# ranking of feature with different models merged into one ranking, weighted by amount of models
def model_rank(rankings):
    # get all used features
    features = list(rankings[0].Feature)
    for i in range(len(rankings)):
        for feat in list(rankings[i].Feature):
            if feat not in features:
                features.append(feat)

    # calculate rankings between all models
    score = pd.DataFrame([0]*len(features), index=features, columns=['Score'])
    for i in range(len(rankings)):
        for feat in rankings[i].Feature:
        # if already calculated, continue
            if score.Score.loc[feat] != 0:
                continue
        # if not, calculated score
            score_sum = 0
            for j in range(len(rankings)):
                if feat in list(rankings[j].Feature):
                    score_sum += rankings[j].loc[rankings[j].Feature == feat, 'Rank'].iloc[0]
                # penalty if feature is not in another ranking
                if feat not in list(rankings[j].Feature):
                    score_sum += len(features)
            score.loc[feat].Score=score_sum
            
    score['Score'].replace({0 : np.inf}, inplace=True)
    
    return score.sort_values('Score')

# input X, y get chi2 ranking regarding y
def chi2_rank(X_enc, y_enc):
    sel_chi2 = SelectKBest(chi2, k=len(X_enc.columns))
    sel_chi2.fit_transform(X_enc, y_enc)
    num_names = X_enc.columns.values[sel_chi2.get_support()]
    num_scores = sel_chi2.scores_[sel_chi2.get_support()]
    num_names_scores = list(zip(num_names, num_scores))
    chi2_df = pd.DataFrame(data = num_names_scores, columns=['Feature', 0])
    # get all ranked
    chi2_ranked = topKfeat(chi2_df, len(X_enc.columns))
    return chi2_ranked
   
# input X, y get f1 ranking regarding y
def f1_rank(X_enc, y_enc):
    sel_f_score = SelectKBest(f_classif, k=len(X_enc.columns))
    sel_f_score.fit_transform(X_enc, y_enc)
    num_names = X_enc.columns.values[sel_f_score.get_support()]
    num_scores = sel_f_score.scores_[sel_f_score.get_support()]
    num_names_scores = list(zip(num_names, num_scores))
    f_df = pd.DataFrame(data = num_names_scores, columns=['Feature', 0])
    # get all ranked
    f_ranked = topKfeat(f_df, len(X_enc.columns))
    return f_ranked

# input X, y get feature importance of each feature regarding y with untrained random forest rf
def rf_rank(X_train, y_train, rf):
    # train rf with the parameters decided above
    rf.fit(X_train,y_train)

    # get feature importance
    rf_feat_imp = pd.DataFrame(rf.feature_importances_)
    rf_feat_imp['Feature'] = X_train.columns

    return topKfeat(rf_feat_imp, len(X_train.columns))

# input X, y get permutated feature importance of each feature regarding y with untrained svc 
def svc_rank(X_train, y_train, svc):
    # train svc with parameters decided above
    svc.fit(X_train,y_train)
    # get feature permutation importances
    perm_imp_svc = permutation_importance(svc, X_train, y_train, random_state=42, n_jobs=-1, scoring='accuracy')
    # save as df
    svc_feat_imp = pd.DataFrame(X_train.columns, columns=['Feature'])
    svc_feat_imp[0] = perm_imp_svc.importances_mean
    
    return topKfeat(svc_feat_imp, len(X_train.columns))

# input X, y get permutated feature importance of each feature regarding y with nn
def nn_rank(X_train, y_train_ohe, nn):
    tf.random.set_seed(1)
    nn.fit(X_train, y_train_ohe)
    
    perm_nn = PermutationImportance(nn, random_state=42).fit(X_train,y_train_ohe)
    nn_feat_imp = eli5.explain_weights_df(perm_nn, feature_names=X_train.columns.tolist()).iloc[:,:-1]
    nn_feat_imp.columns = ['Feature', 0]
    return topKfeat(nn_feat_imp, len(X_train.columns))

# %%
# generate feature ranking for each model
chi2_ranking = chi2_rank(X_enc, y_enc)
f1_ranking = f1_rank(X_enc, y_enc)
rf_ranking = rf_rank(X_train, y_train, rf)
svc_ranking = svc_rank(X_train_svc, y_train, svc)
nn_ranking = nn_rank(X_train_svc, y_train, nn)
# Out:
# Epoch 1/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.6647 - accuracy: 0.6179 - mse: 0.2359
# Epoch 2/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.5008 - accuracy: 0.7994 - mse: 0.1624
# Epoch 3/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4067 - accuracy: 0.8191 - mse: 0.1292
# Epoch 4/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3945 - accuracy: 0.8289 - mse: 0.1254
# Epoch 5/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3888 - accuracy: 0.8357 - mse: 0.1234
# Epoch 6/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3688 - accuracy: 0.8341 - mse: 0.1175
# Epoch 7/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3613 - accuracy: 0.8419 - mse: 0.1160
# Epoch 8/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3595 - accuracy: 0.8409 - mse: 0.1155
# Epoch 9/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3568 - accuracy: 0.8388 - mse: 0.1149
# Epoch 10/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3540 - accuracy: 0.8383 - mse: 0.1147
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3493 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3584 - accuracy: 0.8331 - mse: 0.1166
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3510 - accuracy: 0.8377 - mse: 0.1140
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3496 - accuracy: 0.8424 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3495 - accuracy: 0.8424 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3496 - accuracy: 0.8424 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3508 - accuracy: 0.8419 - mse: 0.1136
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3518 - accuracy: 0.8362 - mse: 0.1142
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8429 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3510 - accuracy: 0.8403 - mse: 0.1136
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3576 - accuracy: 0.8388 - mse: 0.1163
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8419 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3497 - accuracy: 0.8460 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3511 - accuracy: 0.8409 - mse: 0.1139
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3663 - accuracy: 0.8294 - mse: 0.1192
# 39/39 [==============================] - 0s 3ms/step - loss: 0.3586 - accuracy: 0.8377 - mse: 0.1166
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3494 - accuracy: 0.8429 - mse: 0.1131
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3603 - accuracy: 0.8331 - mse: 0.1169
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3493 - accuracy: 0.8414 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3502 - accuracy: 0.8419 - mse: 0.1134
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3495 - accuracy: 0.8419 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3498 - accuracy: 0.8403 - mse: 0.1130
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3508 - accuracy: 0.8429 - mse: 0.1136
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8419 - mse: 0.1131
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3551 - accuracy: 0.8383 - mse: 0.1152
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3503 - accuracy: 0.8419 - mse: 0.1135
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3492 - accuracy: 0.8414 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3675 - accuracy: 0.8284 - mse: 0.1193
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3634 - accuracy: 0.8263 - mse: 0.1189
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3500 - accuracy: 0.8409 - mse: 0.1134
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3493 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3488 - accuracy: 0.8419 - mse: 0.1130
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3507 - accuracy: 0.8419 - mse: 0.1136
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3504 - accuracy: 0.8419 - mse: 0.1135
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3501 - accuracy: 0.8398 - mse: 0.1134
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3501 - accuracy: 0.8398 - mse: 0.1136
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3497 - accuracy: 0.8429 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3496 - accuracy: 0.8424 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3534 - accuracy: 0.8419 - mse: 0.1139
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3494 - accuracy: 0.8424 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3520 - accuracy: 0.8388 - mse: 0.1144
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3496 - accuracy: 0.8419 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3501 - accuracy: 0.8424 - mse: 0.1134
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3501 - accuracy: 0.8377 - mse: 0.1136
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3497 - accuracy: 0.8429 - mse: 0.1133
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3511 - accuracy: 0.8414 - mse: 0.1139
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3499 - accuracy: 0.8424 - mse: 0.1134
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3494 - accuracy: 0.8419 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3518 - accuracy: 0.8414 - mse: 0.1139
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3518 - accuracy: 0.8414 - mse: 0.1138
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3493 - accuracy: 0.8429 - mse: 0.1131
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3633 - accuracy: 0.8341 - mse: 0.1181
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3547 - accuracy: 0.8403 - mse: 0.1152
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3517 - accuracy: 0.8409 - mse: 0.1140
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3543 - accuracy: 0.8398 - mse: 0.1149
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3590 - accuracy: 0.8398 - mse: 0.1156
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3582 - accuracy: 0.8398 - mse: 0.1163
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3495 - accuracy: 0.8424 - mse: 0.1132
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3508 - accuracy: 0.8351 - mse: 0.1141
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3496 - accuracy: 0.8393 - mse: 0.1130
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3504 - accuracy: 0.8424 - mse: 0.1134
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3495 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3506 - accuracy: 0.8419 - mse: 0.1136
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3507 - accuracy: 0.8419 - mse: 0.1136
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3497 - accuracy: 0.8424 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3496 - accuracy: 0.8424 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.4303 - accuracy: 0.7932 - mse: 0.1431
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3521 - accuracy: 0.8377 - mse: 0.1143
# 39/39 [==============================] - 0s 1ms/step - loss: 0.4900 - accuracy: 0.7698 - mse: 0.1603
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3538 - accuracy: 0.8393 - mse: 0.1147
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3803 - accuracy: 0.8149 - mse: 0.1253
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3496 - accuracy: 0.8424 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3573 - accuracy: 0.8357 - mse: 0.1162
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8429 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3496 - accuracy: 0.8424 - mse: 0.1133
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8429 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3509 - accuracy: 0.8409 - mse: 0.1137
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3508 - accuracy: 0.8398 - mse: 0.1138
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3522 - accuracy: 0.8398 - mse: 0.1142
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8434 - mse: 0.1132
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3559 - accuracy: 0.8362 - mse: 0.1156
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3544 - accuracy: 0.8372 - mse: 0.1150
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8429 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3513 - accuracy: 0.8414 - mse: 0.1140
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3493 - accuracy: 0.8424 - mse: 0.1130
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3621 - accuracy: 0.8372 - mse: 0.1172
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3605 - accuracy: 0.8326 - mse: 0.1176
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3493 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3589 - accuracy: 0.8383 - mse: 0.1161
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3492 - accuracy: 0.8419 - mse: 0.1130
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3525 - accuracy: 0.8393 - mse: 0.1143
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3499 - accuracy: 0.8429 - mse: 0.1133
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3512 - accuracy: 0.8393 - mse: 0.1138
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3517 - accuracy: 0.8409 - mse: 0.1140
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3525 - accuracy: 0.8398 - mse: 0.1141
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3497 - accuracy: 0.8424 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3492 - accuracy: 0.8409 - mse: 0.1132
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3655 - accuracy: 0.8289 - mse: 0.1185
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3625 - accuracy: 0.8258 - mse: 0.1185
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3496 - accuracy: 0.8434 - mse: 0.1132
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3494 - accuracy: 0.8424 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8419 - mse: 0.1132
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3498 - accuracy: 0.8419 - mse: 0.1133
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3504 - accuracy: 0.8409 - mse: 0.1135
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3505 - accuracy: 0.8357 - mse: 0.1137
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3514 - accuracy: 0.8403 - mse: 0.1141
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3493 - accuracy: 0.8429 - mse: 0.1130
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3499 - accuracy: 0.8419 - mse: 0.1133
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3494 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3491 - accuracy: 0.8429 - mse: 0.1129
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3496 - accuracy: 0.8424 - mse: 0.1132
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3512 - accuracy: 0.8393 - mse: 0.1140
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3501 - accuracy: 0.8424 - mse: 0.1134
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3508 - accuracy: 0.8398 - mse: 0.1137
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3493 - accuracy: 0.8419 - mse: 0.1130
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3492 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3499 - accuracy: 0.8419 - mse: 0.1134
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3503 - accuracy: 0.8419 - mse: 0.1135
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3494 - accuracy: 0.8414 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3500 - accuracy: 0.8424 - mse: 0.1134
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3498 - accuracy: 0.8419 - mse: 0.1133
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8429 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3612 - accuracy: 0.8336 - mse: 0.1174
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3528 - accuracy: 0.8388 - mse: 0.1144
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3508 - accuracy: 0.8414 - mse: 0.1137
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3570 - accuracy: 0.8372 - mse: 0.1158
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3578 - accuracy: 0.8398 - mse: 0.1151
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3581 - accuracy: 0.8357 - mse: 0.1164
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3523 - accuracy: 0.8367 - mse: 0.1145
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3512 - accuracy: 0.8377 - mse: 0.1138
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3513 - accuracy: 0.8414 - mse: 0.1138
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3491 - accuracy: 0.8440 - mse: 0.1129
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3508 - accuracy: 0.8419 - mse: 0.1136
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3507 - accuracy: 0.8414 - mse: 0.1136
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3491 - accuracy: 0.8440 - mse: 0.1130
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3496 - accuracy: 0.8424 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.4346 - accuracy: 0.7880 - mse: 0.1445
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3506 - accuracy: 0.8403 - mse: 0.1137
# 39/39 [==============================] - 0s 1ms/step - loss: 0.4954 - accuracy: 0.7615 - mse: 0.1628
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3529 - accuracy: 0.8403 - mse: 0.1144
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3734 - accuracy: 0.8222 - mse: 0.1217
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3495 - accuracy: 0.8424 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3555 - accuracy: 0.8336 - mse: 0.1157
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3504 - accuracy: 0.8419 - mse: 0.1136
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3496 - accuracy: 0.8429 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8429 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3504 - accuracy: 0.8445 - mse: 0.1136
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3505 - accuracy: 0.8367 - mse: 0.1136
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3510 - accuracy: 0.8377 - mse: 0.1138
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3495 - accuracy: 0.8424 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3535 - accuracy: 0.8367 - mse: 0.1148
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3549 - accuracy: 0.8388 - mse: 0.1155
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8429 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3517 - accuracy: 0.8409 - mse: 0.1140
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3507 - accuracy: 0.8424 - mse: 0.1136
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3559 - accuracy: 0.8351 - mse: 0.1155
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3571 - accuracy: 0.8357 - mse: 0.1164
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3493 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3578 - accuracy: 0.8403 - mse: 0.1158
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3492 - accuracy: 0.8429 - mse: 0.1130
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3508 - accuracy: 0.8414 - mse: 0.1136
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3493 - accuracy: 0.8424 - mse: 0.1130
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3508 - accuracy: 0.8393 - mse: 0.1137
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3522 - accuracy: 0.8409 - mse: 0.1143
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3525 - accuracy: 0.8341 - mse: 0.1142
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3504 - accuracy: 0.8419 - mse: 0.1135
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3493 - accuracy: 0.8424 - mse: 0.1132
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3639 - accuracy: 0.8310 - mse: 0.1185
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3633 - accuracy: 0.8289 - mse: 0.1192
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3500 - accuracy: 0.8429 - mse: 0.1133
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3495 - accuracy: 0.8424 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3499 - accuracy: 0.8414 - mse: 0.1134
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3507 - accuracy: 0.8419 - mse: 0.1137
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3499 - accuracy: 0.8398 - mse: 0.1134
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3516 - accuracy: 0.8403 - mse: 0.1140
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3496 - accuracy: 0.8414 - mse: 0.1134
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3507 - accuracy: 0.8419 - mse: 0.1137
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3494 - accuracy: 0.8429 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8424 - mse: 0.1132
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3541 - accuracy: 0.8414 - mse: 0.1145
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3493 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3539 - accuracy: 0.8362 - mse: 0.1152
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3488 - accuracy: 0.8429 - mse: 0.1129
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3507 - accuracy: 0.8429 - mse: 0.1136
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3497 - accuracy: 0.8393 - mse: 0.1133
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3502 - accuracy: 0.8424 - mse: 0.1135
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3503 - accuracy: 0.8419 - mse: 0.1136
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3500 - accuracy: 0.8419 - mse: 0.1134
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3501 - accuracy: 0.8414 - mse: 0.1134
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3505 - accuracy: 0.8424 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3497 - accuracy: 0.8419 - mse: 0.1133
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3494 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3617 - accuracy: 0.8310 - mse: 0.1181
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3543 - accuracy: 0.8393 - mse: 0.1150
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3518 - accuracy: 0.8409 - mse: 0.1141
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3538 - accuracy: 0.8398 - mse: 0.1147
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3563 - accuracy: 0.8398 - mse: 0.1153
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3544 - accuracy: 0.8419 - mse: 0.1148
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3493 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3523 - accuracy: 0.8351 - mse: 0.1146
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3517 - accuracy: 0.8398 - mse: 0.1138
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3495 - accuracy: 0.8424 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3492 - accuracy: 0.8419 - mse: 0.1130
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3492 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3495 - accuracy: 0.8424 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3493 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3497 - accuracy: 0.8424 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.4408 - accuracy: 0.7906 - mse: 0.1472
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3517 - accuracy: 0.8388 - mse: 0.1142
# 39/39 [==============================] - 0s 1ms/step - loss: 0.4780 - accuracy: 0.7735 - mse: 0.1558
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3561 - accuracy: 0.8398 - mse: 0.1150
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3847 - accuracy: 0.8118 - mse: 0.1268
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3496 - accuracy: 0.8424 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3550 - accuracy: 0.8341 - mse: 0.1155
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3498 - accuracy: 0.8362 - mse: 0.1135
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3493 - accuracy: 0.8429 - mse: 0.1132
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3492 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8424 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3500 - accuracy: 0.8409 - mse: 0.1135
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3506 - accuracy: 0.8398 - mse: 0.1136
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3510 - accuracy: 0.8393 - mse: 0.1137
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3494 - accuracy: 0.8429 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3526 - accuracy: 0.8357 - mse: 0.1145
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3550 - accuracy: 0.8331 - mse: 0.1155
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8419 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3521 - accuracy: 0.8388 - mse: 0.1144
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8419 - mse: 0.1132
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3641 - accuracy: 0.8320 - mse: 0.1181
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3595 - accuracy: 0.8367 - mse: 0.1171
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8429 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3583 - accuracy: 0.8346 - mse: 0.1162
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3493 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3515 - accuracy: 0.8383 - mse: 0.1139
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3499 - accuracy: 0.8414 - mse: 0.1133
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3508 - accuracy: 0.8403 - mse: 0.1135
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3514 - accuracy: 0.8409 - mse: 0.1140
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3493 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3532 - accuracy: 0.8388 - mse: 0.1146
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3499 - accuracy: 0.8419 - mse: 0.1133
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8419 - mse: 0.1133
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3703 - accuracy: 0.8248 - mse: 0.1208
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3636 - accuracy: 0.8305 - mse: 0.1190
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3496 - accuracy: 0.8409 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3493 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3496 - accuracy: 0.8419 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3504 - accuracy: 0.8409 - mse: 0.1136
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3504 - accuracy: 0.8414 - mse: 0.1135
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3503 - accuracy: 0.8434 - mse: 0.1134
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3498 - accuracy: 0.8403 - mse: 0.1135
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3487 - accuracy: 0.8434 - mse: 0.1128
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3498 - accuracy: 0.8424 - mse: 0.1133
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3533 - accuracy: 0.8414 - mse: 0.1141
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3501 - accuracy: 0.8419 - mse: 0.1134
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3508 - accuracy: 0.8393 - mse: 0.1138
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8424 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3512 - accuracy: 0.8409 - mse: 0.1138
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3512 - accuracy: 0.8424 - mse: 0.1138
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3496 - accuracy: 0.8429 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3510 - accuracy: 0.8393 - mse: 0.1138
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3508 - accuracy: 0.8414 - mse: 0.1136
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3493 - accuracy: 0.8414 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3517 - accuracy: 0.8414 - mse: 0.1138
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3495 - accuracy: 0.8419 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8419 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3656 - accuracy: 0.8279 - mse: 0.1196
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3538 - accuracy: 0.8393 - mse: 0.1149
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3502 - accuracy: 0.8424 - mse: 0.1134
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3543 - accuracy: 0.8409 - mse: 0.1146
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3595 - accuracy: 0.8393 - mse: 0.1160
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3594 - accuracy: 0.8351 - mse: 0.1168
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3524 - accuracy: 0.8362 - mse: 0.1147
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3521 - accuracy: 0.8414 - mse: 0.1141
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3508 - accuracy: 0.8419 - mse: 0.1136
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3492 - accuracy: 0.8419 - mse: 0.1130
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3493 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3505 - accuracy: 0.8419 - mse: 0.1135
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3493 - accuracy: 0.8419 - mse: 0.1130
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3491 - accuracy: 0.8424 - mse: 0.1130
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3497 - accuracy: 0.8424 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.4268 - accuracy: 0.7895 - mse: 0.1435
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3525 - accuracy: 0.8383 - mse: 0.1145
# 39/39 [==============================] - 0s 1ms/step - loss: 0.4800 - accuracy: 0.7641 - mse: 0.1590
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3522 - accuracy: 0.8409 - mse: 0.1141
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3746 - accuracy: 0.8232 - mse: 0.1226
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3492 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3543 - accuracy: 0.8310 - mse: 0.1152
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3514 - accuracy: 0.8393 - mse: 0.1140
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3495 - accuracy: 0.8424 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3496 - accuracy: 0.8429 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3503 - accuracy: 0.8351 - mse: 0.1135
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3508 - accuracy: 0.8377 - mse: 0.1136
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8429 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3544 - accuracy: 0.8367 - mse: 0.1150
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3565 - accuracy: 0.8331 - mse: 0.1162
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3495 - accuracy: 0.8429 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3518 - accuracy: 0.8440 - mse: 0.1140
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3504 - accuracy: 0.8393 - mse: 0.1136
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3621 - accuracy: 0.8367 - mse: 0.1172
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3612 - accuracy: 0.8362 - mse: 0.1173
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8429 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3597 - accuracy: 0.8393 - mse: 0.1164
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8429 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3521 - accuracy: 0.8398 - mse: 0.1142
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3500 - accuracy: 0.8414 - mse: 0.1134
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3503 - accuracy: 0.8414 - mse: 0.1136
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3497 - accuracy: 0.8403 - mse: 0.1133
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3493 - accuracy: 0.8434 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3518 - accuracy: 0.8377 - mse: 0.1141
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3493 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3499 - accuracy: 0.8424 - mse: 0.1134
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3638 - accuracy: 0.8294 - mse: 0.1179
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3629 - accuracy: 0.8346 - mse: 0.1185
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3495 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3493 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3490 - accuracy: 0.8424 - mse: 0.1130
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3497 - accuracy: 0.8409 - mse: 0.1135
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3512 - accuracy: 0.8419 - mse: 0.1138
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3522 - accuracy: 0.8398 - mse: 0.1142
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3504 - accuracy: 0.8419 - mse: 0.1135
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3505 - accuracy: 0.8419 - mse: 0.1136
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3496 - accuracy: 0.8424 - mse: 0.1132
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3494 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3526 - accuracy: 0.8419 - mse: 0.1138
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3491 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3508 - accuracy: 0.8393 - mse: 0.1137
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3491 - accuracy: 0.8419 - mse: 0.1130
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3488 - accuracy: 0.8424 - mse: 0.1129
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3508 - accuracy: 0.8383 - mse: 0.1136
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3504 - accuracy: 0.8414 - mse: 0.1135
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3504 - accuracy: 0.8414 - mse: 0.1136
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3496 - accuracy: 0.8419 - mse: 0.1133
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3493 - accuracy: 0.8414 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3499 - accuracy: 0.8424 - mse: 0.1133
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3517 - accuracy: 0.8414 - mse: 0.1138
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8424 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3659 - accuracy: 0.8346 - mse: 0.1195
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3537 - accuracy: 0.8429 - mse: 0.1148
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3497 - accuracy: 0.8414 - mse: 0.1133
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3554 - accuracy: 0.8414 - mse: 0.1148
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3584 - accuracy: 0.8388 - mse: 0.1159
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3571 - accuracy: 0.8351 - mse: 0.1160
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3493 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3521 - accuracy: 0.8388 - mse: 0.1145
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3508 - accuracy: 0.8398 - mse: 0.1136
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3515 - accuracy: 0.8414 - mse: 0.1139
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3498 - accuracy: 0.8434 - mse: 0.1132
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3511 - accuracy: 0.8424 - mse: 0.1134
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3503 - accuracy: 0.8419 - mse: 0.1135
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3493 - accuracy: 0.8419 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8424 - mse: 0.1131
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3497 - accuracy: 0.8424 - mse: 0.1133
# 39/39 [==============================] - 0s 1ms/step - loss: 0.4315 - accuracy: 0.7921 - mse: 0.1436
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3507 - accuracy: 0.8388 - mse: 0.1138
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4910 - accuracy: 0.7678 - mse: 0.1614
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3588 - accuracy: 0.8403 - mse: 0.1154
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3723 - accuracy: 0.8196 - mse: 0.1220
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3501 - accuracy: 0.8424 - mse: 0.1134

# %%
def all_rank(ranks, X_columns):
    rank_all = model_rank(ranks)
    rank_all['Feature'] = rank_all.index
    rank_all.index = [i for i in range(len(X_columns))]
# could be done with loop, but needs thinking about it
    all_rank = pd.DataFrame()
    all_rank['rank'] = ranks[0].Rank
    all_rank['chi2_feat'] = ranks[0].Feature
    all_rank['f_feat'] = ranks[1].Feature
    all_rank['rf_feat'] = ranks[2].Feature
    all_rank['svc_feat'] = ranks[3].Feature
    all_rank['nn_feat'] = ranks[4].Feature
    all_rank['final_score'] = rank_all.Score
    all_rank['final_feat'] = rank_all.Feature
    return all_rank

def metrics(y_true, y_pred):
    metrics = [accuracy_score(y_true, y_pred), \
               recall_score(y_true, y_pred), \
               precision_score(y_true, y_pred), \
               f1_score(y_true, y_pred), \
               roc_auc_score(y_true, y_pred),\
              hamming_loss(y_true, y_pred)]
    return metrics

# %%
# generate final feature ranking
all_ranking = all_rank([chi2_ranking, f1_ranking, rf_ranking, svc_ranking, nn_ranking], X_train.columns)

# %%
evaluation = pd.DataFrame(index=['Accuracy','Recall', 'Precision', 'F1', 'ROC_AUC', 'Loss'])


#models with 2+3*k features wiht k in [0,12]
for j in range(2,41,3):
    i = all_ranking.iloc[:j, -1:]
    
    # random forest
    rf.fit(X_train[i.final_feat], y_train)
    y_pred_rf = rf.predict(X_test[i.final_feat])
    evaluation['RF '+str(len(i.final_feat))] = metrics(y_test, y_pred_rf)
    
    # svc
    svc.fit(X_train_svc[i.final_feat], y_train)
    y_pred_svc = svc.predict(X_test_svc[i.final_feat])
    evaluation['SVC '+str(len(i.final_feat))] = metrics(y_test, y_pred_svc)
    
    #nn
    nn.fit(X_train_svc[i.final_feat], y_train)
    y_pred_nn = nn.predict(X_test_svc[i.final_feat])
    evaluation['NN '+str(len(i.final_feat))] = metrics(y_test, y_pred_nn)
# Out:
# Epoch 1/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.6932 - accuracy: 0.5060 - mse: 0.2500
# Epoch 2/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.6739 - accuracy: 0.6153 - mse: 0.2404
# Epoch 3/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.6191 - accuracy: 0.7506 - mse: 0.2135
# Epoch 4/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.5316 - accuracy: 0.7449 - mse: 0.1750
# Epoch 5/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4855 - accuracy: 0.7553 - mse: 0.1599
# Epoch 6/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4683 - accuracy: 0.7558 - mse: 0.1555
# Epoch 7/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4502 - accuracy: 0.7678 - mse: 0.1504
# Epoch 8/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4505 - accuracy: 0.7595 - mse: 0.1518
# Epoch 9/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4415 - accuracy: 0.7750 - mse: 0.1491
# Epoch 10/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4379 - accuracy: 0.7797 - mse: 0.1484
# Epoch 1/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.6903 - accuracy: 0.5117 - mse: 0.2486
# Epoch 2/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.6490 - accuracy: 0.6729 - mse: 0.2282
# Epoch 3/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.5482 - accuracy: 0.7693 - mse: 0.1815
# Epoch 4/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4821 - accuracy: 0.7636 - mse: 0.1578
# Epoch 5/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4695 - accuracy: 0.7745 - mse: 0.1536
# Epoch 6/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4511 - accuracy: 0.7880 - mse: 0.1477
# Epoch 7/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4334 - accuracy: 0.7937 - mse: 0.1420
# Epoch 8/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4308 - accuracy: 0.7906 - mse: 0.1422
# Epoch 9/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4221 - accuracy: 0.7906 - mse: 0.1400
# Epoch 10/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4169 - accuracy: 0.7911 - mse: 0.1388
# Epoch 1/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.6862 - accuracy: 0.5179 - mse: 0.2465
# Epoch 2/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.6085 - accuracy: 0.7424 - mse: 0.2088
# Epoch 3/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4732 - accuracy: 0.7833 - mse: 0.1528
# Epoch 4/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4456 - accuracy: 0.7786 - mse: 0.1472
# Epoch 5/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4451 - accuracy: 0.7890 - mse: 0.1459
# Epoch 6/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4291 - accuracy: 0.7906 - mse: 0.1419
# Epoch 7/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4200 - accuracy: 0.7973 - mse: 0.1387
# Epoch 8/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4214 - accuracy: 0.7937 - mse: 0.1399
# Epoch 9/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4175 - accuracy: 0.7875 - mse: 0.1389
# Epoch 10/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4122 - accuracy: 0.7937 - mse: 0.1372
# Epoch 1/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.6831 - accuracy: 0.5329 - mse: 0.2450
# Epoch 2/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.5830 - accuracy: 0.7880 - mse: 0.1968
# Epoch 3/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4334 - accuracy: 0.8154 - mse: 0.1373
# Epoch 4/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4143 - accuracy: 0.8056 - mse: 0.1338
# Epoch 5/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4159 - accuracy: 0.8191 - mse: 0.1334
# Epoch 6/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3991 - accuracy: 0.8201 - mse: 0.1287
# Epoch 7/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3921 - accuracy: 0.8180 - mse: 0.1266
# Epoch 8/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3927 - accuracy: 0.8191 - mse: 0.1271
# Epoch 9/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3918 - accuracy: 0.8243 - mse: 0.1270
# Epoch 10/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3870 - accuracy: 0.8217 - mse: 0.1256
# Epoch 1/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.6788 - accuracy: 0.5594 - mse: 0.2429
# Epoch 2/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.5561 - accuracy: 0.7916 - mse: 0.1850
# Epoch 3/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4232 - accuracy: 0.8118 - mse: 0.1348
# Epoch 4/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4086 - accuracy: 0.8123 - mse: 0.1319
# Epoch 5/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4067 - accuracy: 0.8129 - mse: 0.1309
# Epoch 6/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3902 - accuracy: 0.8217 - mse: 0.1261
# Epoch 7/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3814 - accuracy: 0.8258 - mse: 0.1234
# Epoch 8/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3818 - accuracy: 0.8227 - mse: 0.1239
# Epoch 9/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3809 - accuracy: 0.8232 - mse: 0.1238
# Epoch 10/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3769 - accuracy: 0.8248 - mse: 0.1227
# Epoch 1/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.6783 - accuracy: 0.5619 - mse: 0.2426
# Epoch 2/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.5535 - accuracy: 0.7885 - mse: 0.1840
# Epoch 3/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4260 - accuracy: 0.8113 - mse: 0.1357
# Epoch 4/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4101 - accuracy: 0.8118 - mse: 0.1321
# Epoch 5/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4063 - accuracy: 0.8165 - mse: 0.1303
# Epoch 6/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3898 - accuracy: 0.8232 - mse: 0.1257
# Epoch 7/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3812 - accuracy: 0.8243 - mse: 0.1232
# Epoch 8/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3813 - accuracy: 0.8263 - mse: 0.1236
# Epoch 9/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3804 - accuracy: 0.8217 - mse: 0.1235
# Epoch 10/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3763 - accuracy: 0.8248 - mse: 0.1224
# Epoch 1/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.6774 - accuracy: 0.5734 - mse: 0.2422
# Epoch 2/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.5482 - accuracy: 0.7926 - mse: 0.1817
# Epoch 3/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4209 - accuracy: 0.8123 - mse: 0.1336
# Epoch 4/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4043 - accuracy: 0.8134 - mse: 0.1298
# Epoch 5/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3993 - accuracy: 0.8258 - mse: 0.1276
# Epoch 6/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3830 - accuracy: 0.8258 - mse: 0.1232
# Epoch 7/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3756 - accuracy: 0.8274 - mse: 0.1214
# Epoch 8/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3758 - accuracy: 0.8279 - mse: 0.1217
# Epoch 9/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3743 - accuracy: 0.8263 - mse: 0.1214
# Epoch 10/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3702 - accuracy: 0.8243 - mse: 0.1204
# Epoch 1/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.6756 - accuracy: 0.5832 - mse: 0.2413
# Epoch 2/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.5413 - accuracy: 0.7973 - mse: 0.1789
# Epoch 3/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4234 - accuracy: 0.8144 - mse: 0.1348
# Epoch 4/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4076 - accuracy: 0.8154 - mse: 0.1308
# Epoch 5/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4013 - accuracy: 0.8243 - mse: 0.1284
# Epoch 6/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3841 - accuracy: 0.8263 - mse: 0.1235
# Epoch 7/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3759 - accuracy: 0.8274 - mse: 0.1215
# Epoch 8/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3756 - accuracy: 0.8289 - mse: 0.1216
# Epoch 9/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3736 - accuracy: 0.8258 - mse: 0.1213
# Epoch 10/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3694 - accuracy: 0.8232 - mse: 0.1202
# Epoch 1/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.6750 - accuracy: 0.5811 - mse: 0.2410
# Epoch 2/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.5383 - accuracy: 0.7963 - mse: 0.1776
# Epoch 3/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4233 - accuracy: 0.8160 - mse: 0.1346
# Epoch 4/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4064 - accuracy: 0.8212 - mse: 0.1301
# Epoch 5/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4003 - accuracy: 0.8222 - mse: 0.1281
# Epoch 6/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3826 - accuracy: 0.8305 - mse: 0.1229
# Epoch 7/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3737 - accuracy: 0.8305 - mse: 0.1209
# Epoch 8/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3734 - accuracy: 0.8300 - mse: 0.1209
# Epoch 9/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3708 - accuracy: 0.8279 - mse: 0.1204
# Epoch 10/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3672 - accuracy: 0.8289 - mse: 0.1195
# Epoch 1/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.6731 - accuracy: 0.5931 - mse: 0.2400
# Epoch 2/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.5298 - accuracy: 0.7983 - mse: 0.1740
# Epoch 3/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4219 - accuracy: 0.8144 - mse: 0.1340
# Epoch 4/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4069 - accuracy: 0.8201 - mse: 0.1298
# Epoch 5/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3976 - accuracy: 0.8243 - mse: 0.1270
# Epoch 6/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3802 - accuracy: 0.8284 - mse: 0.1218
# Epoch 7/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3715 - accuracy: 0.8346 - mse: 0.1198
# Epoch 8/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3706 - accuracy: 0.8336 - mse: 0.1197
# Epoch 9/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3672 - accuracy: 0.8315 - mse: 0.1189
# Epoch 10/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3636 - accuracy: 0.8289 - mse: 0.1182
# Epoch 1/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.6711 - accuracy: 0.5993 - mse: 0.2391
# Epoch 2/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.5231 - accuracy: 0.7963 - mse: 0.1712
# Epoch 3/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4204 - accuracy: 0.8160 - mse: 0.1333
# Epoch 4/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4078 - accuracy: 0.8175 - mse: 0.1299
# Epoch 5/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3984 - accuracy: 0.8279 - mse: 0.1271
# Epoch 6/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3805 - accuracy: 0.8300 - mse: 0.1218
# Epoch 7/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3712 - accuracy: 0.8310 - mse: 0.1197
# Epoch 8/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3702 - accuracy: 0.8341 - mse: 0.1196
# Epoch 9/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3665 - accuracy: 0.8320 - mse: 0.1187
# Epoch 10/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3628 - accuracy: 0.8305 - mse: 0.1181
# Epoch 1/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.6709 - accuracy: 0.6013 - mse: 0.2390
# Epoch 2/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.5194 - accuracy: 0.7983 - mse: 0.1697
# Epoch 3/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4154 - accuracy: 0.8186 - mse: 0.1316
# Epoch 4/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4024 - accuracy: 0.8222 - mse: 0.1279
# Epoch 5/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3956 - accuracy: 0.8263 - mse: 0.1256
# Epoch 6/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3769 - accuracy: 0.8320 - mse: 0.1202
# Epoch 7/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3699 - accuracy: 0.8336 - mse: 0.1190
# Epoch 8/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3687 - accuracy: 0.8357 - mse: 0.1187
# Epoch 9/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3659 - accuracy: 0.8331 - mse: 0.1181
# Epoch 10/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3623 - accuracy: 0.8320 - mse: 0.1175
# Epoch 1/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.6704 - accuracy: 0.6024 - mse: 0.2387
# Epoch 2/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.5172 - accuracy: 0.7973 - mse: 0.1688
# Epoch 3/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4135 - accuracy: 0.8186 - mse: 0.1312
# Epoch 4/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4018 - accuracy: 0.8243 - mse: 0.1278
# Epoch 5/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3952 - accuracy: 0.8274 - mse: 0.1256
# Epoch 6/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3762 - accuracy: 0.8336 - mse: 0.1200
# Epoch 7/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3687 - accuracy: 0.8326 - mse: 0.1186
# Epoch 8/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3673 - accuracy: 0.8393 - mse: 0.1182
# Epoch 9/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3640 - accuracy: 0.8315 - mse: 0.1174
# Epoch 10/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3605 - accuracy: 0.8326 - mse: 0.1169

# %%
# evaluation of models on single values, decision for "best" combination of features
print(evaluation.T.iloc[:, :-1].mean(axis=1).sort_values(ascending=False))
evaluation.T.sort_values(by=['ROC_AUC', 'Accuracy'], ascending=False).style.background_gradient(cmap='BuPu')
# Out:
# SVC 38    0.845456
# SVC 35    0.837173
# SVC 29    0.832741
# SVC 32    0.831077
# SVC 23    0.826642
# SVC 17    0.822285
# SVC 14    0.820836
# SVC 20    0.820058
# RF 38     0.818883
# SVC 26    0.817722
# RF 35     0.811587
# NN 35     0.811522
# SVC 11    0.810599
# RF 29     0.809933
# SVC 2     0.808201
# RF 2      0.808201
# RF 32     0.807689
# NN 38     0.807024
# SVC 8     0.803979
# RF 26     0.800503
# RF 5      0.798484
# SVC 5     0.798484
# RF 17     0.796272
# NN 17     0.794571
# RF 20     0.794163
# NN 32     0.792365
# NN 20     0.789501
# NN 14     0.789448
# RF 23     0.789024
# NN 23     0.787821
# NN 11     0.786595
# NN 29     0.785088
# RF 14     0.784905
# NN 26     0.781152
# NN 5      0.778871
# RF 11     0.774600
# RF 8      0.764295
# NN 8      0.761865
# NN 2      0.715136
# dtype: float64
# <style type="text/css">
# #T_a7c5c_row0_col0, #T_a7c5c_row0_col2, #T_a7c5c_row0_col3, #T_a7c5c_row0_col4, #T_a7c5c_row32_col1, #T_a7c5c_row33_col1, #T_a7c5c_row38_col5 {
#   background-color: #4d004b;
#   color: #f1f1f1;
# }
# #T_a7c5c_row0_col1, #T_a7c5c_row4_col0, #T_a7c5c_row6_col2, #T_a7c5c_row9_col3 {
#   background-color: #831f86;
#   color: #f1f1f1;
# }
# #T_a7c5c_row0_col5, #T_a7c5c_row32_col2, #T_a7c5c_row33_col2, #T_a7c5c_row38_col0, #T_a7c5c_row38_col1, #T_a7c5c_row38_col3, #T_a7c5c_row38_col4 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_a7c5c_row1_col0 {
#   background-color: #6a0867;
#   color: #f1f1f1;
# }
# #T_a7c5c_row1_col1, #T_a7c5c_row9_col1 {
#   background-color: #852f91;
#   color: #f1f1f1;
# }
# #T_a7c5c_row1_col2 {
#   background-color: #650762;
#   color: #f1f1f1;
# }
# #T_a7c5c_row1_col3 {
#   background-color: #640761;
#   color: #f1f1f1;
# }
# #T_a7c5c_row1_col4, #T_a7c5c_row3_col2 {
#   background-color: #6c0968;
#   color: #f1f1f1;
# }
# #T_a7c5c_row1_col5 {
#   background-color: #eaf3f8;
#   color: #000000;
# }
# #T_a7c5c_row2_col0, #T_a7c5c_row2_col4, #T_a7c5c_row3_col0, #T_a7c5c_row3_col4 {
#   background-color: #7b0d76;
#   color: #f1f1f1;
# }
# #T_a7c5c_row2_col1, #T_a7c5c_row9_col4 {
#   background-color: #8947a0;
#   color: #f1f1f1;
# }
# #T_a7c5c_row2_col2 {
#   background-color: #520150;
#   color: #f1f1f1;
# }
# #T_a7c5c_row2_col3 {
#   background-color: #760c71;
#   color: #f1f1f1;
# }
# #T_a7c5c_row2_col5, #T_a7c5c_row3_col5 {
#   background-color: #e3eef5;
#   color: #000000;
# }
# #T_a7c5c_row3_col1 {
#   background-color: #873a98;
#   color: #f1f1f1;
# }
# #T_a7c5c_row3_col3 {
#   background-color: #710a6d;
#   color: #f1f1f1;
# }
# #T_a7c5c_row4_col1, #T_a7c5c_row8_col1 {
#   background-color: #88439e;
#   color: #f1f1f1;
# }
# #T_a7c5c_row4_col2 {
#   background-color: #810f7c;
#   color: #f1f1f1;
# }
# #T_a7c5c_row4_col3 {
#   background-color: #81117d;
#   color: #f1f1f1;
# }
# #T_a7c5c_row4_col4 {
#   background-color: #832088;
#   color: #f1f1f1;
# }
# #T_a7c5c_row4_col5 {
#   background-color: #d6e4f0;
#   color: #000000;
# }
# #T_a7c5c_row5_col0, #T_a7c5c_row11_col2 {
#   background-color: #863595;
#   color: #f1f1f1;
# }
# #T_a7c5c_row5_col1, #T_a7c5c_row6_col4, #T_a7c5c_row7_col4, #T_a7c5c_row13_col3 {
#   background-color: #883e9b;
#   color: #f1f1f1;
# }
# #T_a7c5c_row5_col2, #T_a7c5c_row6_col0, #T_a7c5c_row7_col0, #T_a7c5c_row8_col0, #T_a7c5c_row10_col3 {
#   background-color: #873d9a;
#   color: #f1f1f1;
# }
# #T_a7c5c_row5_col3 {
#   background-color: #831c84;
#   color: #f1f1f1;
# }
# #T_a7c5c_row5_col4 {
#   background-color: #873897;
#   color: #f1f1f1;
# }
# #T_a7c5c_row5_col5 {
#   background-color: #c7d9e9;
#   color: #000000;
# }
# #T_a7c5c_row6_col1 {
#   background-color: #8a54a6;
#   color: #f1f1f1;
# }
# #T_a7c5c_row6_col3 {
#   background-color: #852a8e;
#   color: #f1f1f1;
# }
# #T_a7c5c_row6_col5, #T_a7c5c_row7_col5, #T_a7c5c_row8_col5 {
#   background-color: #c2d5e7;
#   color: #000000;
# }
# #T_a7c5c_row7_col1, #T_a7c5c_row17_col3, #T_a7c5c_row28_col2, #T_a7c5c_row36_col2 {
#   background-color: #894ca2;
#   color: #f1f1f1;
# }
# #T_a7c5c_row7_col2 {
#   background-color: #863092;
#   color: #f1f1f1;
# }
# #T_a7c5c_row7_col3 {
#   background-color: #84258b;
#   color: #f1f1f1;
# }
# #T_a7c5c_row8_col2, #T_a7c5c_row13_col2, #T_a7c5c_row27_col2 {
#   background-color: #88419d;
#   color: #f1f1f1;
# }
# #T_a7c5c_row8_col3 {
#   background-color: #842289;
#   color: #f1f1f1;
# }
# #T_a7c5c_row8_col4, #T_a7c5c_row32_col3, #T_a7c5c_row33_col3 {
#   background-color: #88409c;
#   color: #f1f1f1;
# }
# #T_a7c5c_row9_col0, #T_a7c5c_row14_col2, #T_a7c5c_row14_col3, #T_a7c5c_row21_col2 {
#   background-color: #88449e;
#   color: #f1f1f1;
# }
# #T_a7c5c_row9_col2, #T_a7c5c_row19_col1, #T_a7c5c_row22_col3 {
#   background-color: #8b65ae;
#   color: #f1f1f1;
# }
# #T_a7c5c_row9_col5 {
#   background-color: #bdd1e5;
#   color: #000000;
# }
# #T_a7c5c_row10_col0, #T_a7c5c_row10_col4 {
#   background-color: #894ba2;
#   color: #f1f1f1;
# }
# #T_a7c5c_row10_col1, #T_a7c5c_row21_col3 {
#   background-color: #8c6ab1;
#   color: #f1f1f1;
# }
# #T_a7c5c_row10_col2 {
#   background-color: #800f7b;
#   color: #f1f1f1;
# }
# #T_a7c5c_row10_col5 {
#   background-color: #b7cee3;
#   color: #000000;
# }
# #T_a7c5c_row11_col0 {
#   background-color: #8950a4;
#   color: #f1f1f1;
# }
# #T_a7c5c_row11_col1, #T_a7c5c_row13_col1, #T_a7c5c_row14_col0, #T_a7c5c_row23_col1, #T_a7c5c_row24_col1, #T_a7c5c_row36_col5, #T_a7c5c_row37_col5 {
#   background-color: #8b5daa;
#   color: #f1f1f1;
# }
# #T_a7c5c_row11_col3, #T_a7c5c_row15_col3 {
#   background-color: #873b99;
#   color: #f1f1f1;
# }
# #T_a7c5c_row11_col4 {
#   background-color: #8a51a5;
#   color: #f1f1f1;
# }
# #T_a7c5c_row11_col5 {
#   background-color: #b3cbe2;
#   color: #000000;
# }
# #T_a7c5c_row12_col0, #T_a7c5c_row13_col0 {
#   background-color: #8a56a7;
#   color: #f1f1f1;
# }
# #T_a7c5c_row12_col1, #T_a7c5c_row17_col4, #T_a7c5c_row27_col3, #T_a7c5c_row29_col3 {
#   background-color: #8c72b5;
#   color: #f1f1f1;
# }
# #T_a7c5c_row12_col2 {
#   background-color: #821580;
#   color: #f1f1f1;
# }
# #T_a7c5c_row12_col3, #T_a7c5c_row34_col2 {
#   background-color: #8948a0;
#   color: #f1f1f1;
# }
# #T_a7c5c_row12_col4, #T_a7c5c_row13_col4 {
#   background-color: #8a58a8;
#   color: #f1f1f1;
# }
# #T_a7c5c_row12_col5, #T_a7c5c_row13_col5 {
#   background-color: #aec7e0;
#   color: #000000;
# }
# #T_a7c5c_row14_col1 {
#   background-color: #8b61ac;
#   color: #f1f1f1;
# }
# #T_a7c5c_row14_col4 {
#   background-color: #8b5eab;
#   color: #f1f1f1;
# }
# #T_a7c5c_row14_col5, #T_a7c5c_row36_col0, #T_a7c5c_row37_col0 {
#   background-color: #a9c4de;
#   color: #000000;
# }
# #T_a7c5c_row15_col0, #T_a7c5c_row30_col2 {
#   background-color: #8c69b0;
#   color: #f1f1f1;
# }
# #T_a7c5c_row15_col1 {
#   background-color: #863394;
#   color: #f1f1f1;
# }
# #T_a7c5c_row15_col2 {
#   background-color: #8e9ac8;
#   color: #f1f1f1;
# }
# #T_a7c5c_row15_col4 {
#   background-color: #8c6eb3;
#   color: #f1f1f1;
# }
# #T_a7c5c_row15_col5 {
#   background-color: #a0bddb;
#   color: #000000;
# }
# #T_a7c5c_row16_col0, #T_a7c5c_row16_col4, #T_a7c5c_row17_col0 {
#   background-color: #8c70b3;
#   color: #f1f1f1;
# }
# #T_a7c5c_row16_col1, #T_a7c5c_row18_col1, #T_a7c5c_row27_col1, #T_a7c5c_row28_col1, #T_a7c5c_row28_col4, #T_a7c5c_row29_col4, #T_a7c5c_row31_col1 {
#   background-color: #8c91c4;
#   color: #f1f1f1;
# }
# #T_a7c5c_row16_col2 {
#   background-color: #7c0e78;
#   color: #f1f1f1;
# }
# #T_a7c5c_row16_col3 {
#   background-color: #8b64ad;
#   color: #f1f1f1;
# }
# #T_a7c5c_row16_col5, #T_a7c5c_row17_col5, #T_a7c5c_row36_col3 {
#   background-color: #9cb8d8;
#   color: #000000;
# }
# #T_a7c5c_row17_col1, #T_a7c5c_row23_col3, #T_a7c5c_row24_col3 {
#   background-color: #8a59a8;
#   color: #f1f1f1;
# }
# #T_a7c5c_row17_col2 {
#   background-color: #8c71b4;
#   color: #f1f1f1;
# }
# #T_a7c5c_row18_col0, #T_a7c5c_row18_col4, #T_a7c5c_row19_col0, #T_a7c5c_row28_col3 {
#   background-color: #8c76b7;
#   color: #f1f1f1;
# }
# #T_a7c5c_row18_col2, #T_a7c5c_row20_col2 {
#   background-color: #821982;
#   color: #f1f1f1;
# }
# #T_a7c5c_row18_col3, #T_a7c5c_row19_col2 {
#   background-color: #8c68af;
#   color: #f1f1f1;
# }
# #T_a7c5c_row18_col5, #T_a7c5c_row19_col5 {
#   background-color: #99b2d5;
#   color: #000000;
# }
# #T_a7c5c_row19_col3 {
#   background-color: #8a55a7;
#   color: #f1f1f1;
# }
# #T_a7c5c_row19_col4 {
#   background-color: #8c79b8;
#   color: #f1f1f1;
# }
# #T_a7c5c_row20_col0, #T_a7c5c_row20_col4, #T_a7c5c_row21_col0, #T_a7c5c_row22_col0, #T_a7c5c_row23_col0, #T_a7c5c_row24_col0, #T_a7c5c_row25_col3, #T_a7c5c_row31_col5 {
#   background-color: #8c82bc;
#   color: #f1f1f1;
# }
# #T_a7c5c_row20_col1, #T_a7c5c_row30_col4 {
#   background-color: #909eca;
#   color: #f1f1f1;
# }
# #T_a7c5c_row20_col3 {
#   background-color: #8c75b6;
#   color: #f1f1f1;
# }
# #T_a7c5c_row20_col5, #T_a7c5c_row21_col5, #T_a7c5c_row22_col5, #T_a7c5c_row23_col5, #T_a7c5c_row24_col5, #T_a7c5c_row31_col0 {
#   background-color: #94a7cf;
#   color: #f1f1f1;
# }
# #T_a7c5c_row21_col1, #T_a7c5c_row23_col2, #T_a7c5c_row24_col2, #T_a7c5c_row25_col0, #T_a7c5c_row26_col0, #T_a7c5c_row26_col4, #T_a7c5c_row27_col0, #T_a7c5c_row29_col1, #T_a7c5c_row32_col5, #T_a7c5c_row33_col5 {
#   background-color: #8c89c0;
#   color: #f1f1f1;
# }
# #T_a7c5c_row21_col4 {
#   background-color: #8c84bd;
#   color: #f1f1f1;
# }
# #T_a7c5c_row22_col1, #T_a7c5c_row26_col3, #T_a7c5c_row30_col3, #T_a7c5c_row35_col2 {
#   background-col

# %%
# visualisation of metrics of each model type in dependence of amount of used features given by ranking
fig, ax = plt.subplots(3, 2, sharex=True, figsize=(15,10))
ax[0,0].plot([i for i in range(2,41,3)], evaluation.loc['Accuracy', :].filter(regex=("RF.*")), label='RF')
ax[0,0].plot([i for i in range(2,41,3)], evaluation.loc['Accuracy', :].filter(regex=("NN.*")), label='NN')
ax[0,0].plot([i for i in range(2,41,3)], evaluation.loc['Accuracy', :].filter(regex=('SVC.*')), label='SVC')
ax[0,0].set_ylabel('Accuracy')
ax[0,0].legend()
ax[0,1].plot([i for i in range(2,41,3)], evaluation.loc['Recall', :].filter(regex=("RF.*")), label='RF')
ax[0,1].plot([i for i in range(2,41,3)], evaluation.loc['Recall', :].filter(regex=("NN.*")), label='NN')
ax[0,1].plot([i for i in range(2,41,3)], evaluation.loc['Recall', :].filter(regex=('SVC.*')), label='SVC')
ax[0,1].set_ylabel('Recall')
ax[0,1].legend()
ax[1,0].plot([i for i in range(2,41,3)], evaluation.loc['Precision', :].filter(regex=("RF.*")), label='RF')
ax[1,0].plot([i for i in range(2,41,3)], evaluation.loc['Precision', :].filter(regex=("NN.*")), label='NN')
ax[1,0].plot([i for i in range(2,41,3)], evaluation.loc['Precision', :].filter(regex=('SVC.*')), label='SVC')
ax[1,0].set_ylabel('Precision')
ax[1,0].legend()
ax[1,1].plot([i for i in range(2,41,3)], evaluation.loc['F1', :].filter(regex=("RF.*")), label='RF')
ax[1,1].plot([i for i in range(2,41,3)], evaluation.loc['F1', :].filter(regex=("NN.*")), label='NN')
ax[1,1].plot([i for i in range(2,41,3)], evaluation.loc['F1', :].filter(regex=('SVC.*')), label='SVC')
ax[1,1].set_ylabel('F1')
ax[1,1].legend()
ax[2,0].plot([i for i in range(2,41,3)], evaluation.loc['ROC_AUC', :].filter(regex=("RF.*")), label='RF')
ax[2,0].plot([i for i in range(2,41,3)], evaluation.loc['ROC_AUC', :].filter(regex=("NN.*")), label='NN')
ax[2,0].plot([i for i in range(2,41,3)], evaluation.loc['ROC_AUC', :].filter(regex=('SVC.*')), label='SVC')
ax[2,0].set_ylabel('ROC_AUC')
ax[2,0].legend()
ax[2,1].plot([i for i in range(2,41,3)], evaluation.loc['Loss', :].filter(regex=("RF.*")), label='RF')
ax[2,1].plot([i for i in range(2,41,3)], evaluation.loc['Loss', :].filter(regex=("NN.*")), label='NN')
ax[2,1].plot([i for i in range(2,41,3)], evaluation.loc['Loss', :].filter(regex=('SVC.*')), label='SVC')
ax[2,1].set_ylabel('Loss')
ax[2,1].legend()
ax[2,1].set_xlabel('Amount of features')
ax[2,0].set_xlabel('Amount of features')
plt.tight_layout()
plt.savefig('evaluation_balanced.png')
plt.show()

# %%
# display most important 40 features
all_ranking.iloc[:40, -2:]
# Out:
#     final_score                                         final_feat
# 0             6                              ESTANCIA_HOSP_NO HOSP
# 1            19                                 DIAG_CLIN_NEUMONIA
# 2            38  DESC_TIPO_MUESTRA_1_EXUDADO FARINGEO/NASOFARINGEO
# 3            43                               NEUMONIA_RADIOGRAFIA
# 4            55                                     DOLOR_TORACICO
# 5            62                     ESTANCIA_HOSP_MEDICINA INTERNA
# 6            66                                             DISNEA
# 7            90                                               EDAD
# 8            95                        DESC_ESTATUS_CONF1_VALIDADA
# 9           101                                           CIANOSIS
# 10          102                                           RINORREA
# 11          105                    ESTANCIA_HOSP_URGENCIAS ADULTOS
# 12          106                               ANTECED_HIPERTENSION
# 13          114                                 ENFERMEDAD_CRONICA
# 14          119                                   ANTECED_DIABETES
# 15          127                      DESC_RESULTADO_CONF2_NEGATIVO
# 16          130                                         ODINOFAGIA
# 17          135           DESC_TIPO_MUESTRA_1_EXUDADO NASOFARINGEO
# 18          137                                   ANTECED_OBESIDAD
# 19          140                                         POSTRACION
# 20          142                      DESC_RESULTADO_CONF2_POSITIVO
# 21          149                                      ANTECED_RENAL
# 22          150                              RESULTADO_DE MUESTRA1
# 23          152                           ATAQUE_AL_ESTADO_GENERAL
# 24          152                                             GENERO
# 25          154                                 OCUPACION_Jubilado
# 26          157                               INDICADOR_SOSP_COVID
# 27          158                                       ANTECED_EPOC
# 28          160                         DIAGNOSTICO_FINAL_COVID-19
# 29          160                                  OCUPACION_Médicos
# 30          166               DESC_TIPO_MUESTRA_1_EXUDADO FARINGEO
# 31          168                 DIAGNOSTICO_FINAL_Neumonia atipica
# 32          172                           ESTANCIA_HOSP_NEUMOLOGIA
# 33          173                       DESC_ESTATUS_CONF1_RECHAZADA
# 34          182                               OCUPACION_Enfermeras
# 35          182                     DESC_ESTATUS_CONF1_POR RECIBIR
# 36          184                        OCUPACION_Otras Ocupaciones
# 37          190                              OCUPACION_Ama de casa
# 38          191                            OCUPACION_Sin ocupación
# 39          201                                      INICIO_SUBITO
